# %%
import os
import pandas as pd
import sys
import json
from google.protobuf.json_format import Parse

sys.path.insert(0, 'compiled_protobufs')
from taskmap_pb2 import TaskMap

qrels_folder = os.path.join(os.getcwd(), 'measurements', 'judgments')
run_cooking_folder = os.path.join(os.getcwd(), 'measurements', 'cooking', 'run_files')
run_diy_folder = os.path.join(os.getcwd(), 'measurements', 'diy', 'run_files')
# cooking_runs = os.listdir(run_cooking_folder)
# cooking_qrels = os.path.join(qrels_folder, "cooking.qrels")

queries = {
    "COOKING" : pd.read_csv('queries/cooking.csv'),
    "DIY": pd.read_csv('queries/diy.csv'),
}

# %% [markdown]
# ### Full metrics

# %%
# ## cooking results

# from results_helper import get_all_metrics

# # results = {}
# # for searcher in cooking_runs:
# #     run = os.path.join(run_cooking_folder, searcher)
# #     searcher_name = searcher[:-4].lower()
# #     accuracy = get_accuracy(run, cooking_qrles)
# #     results[searcher_name] = accuracy
# #     # print(searcher_name, accuracy)
# # df = pd.DataFrame(results).transpose()
# # df
# path = "/home/ubuntu/task-search-quality/measurements/cooking/analysis/all-metrics"

# get_all_metrics(run_cooking_folder, cooking_qrels, path, with_t5=None)

# %%
path = "/home/ubuntu/task-search-quality/measurements/diy/analysis/all-metrics"
with_t5 = False # True, False, None

diy_qrels = os.path.join(qrels_folder, "diy.qrels")

from results_helper import get_all_metrics, get_all_metrics_searcher

get_all_metrics(run_diy_folder, diy_qrels, path, with_t5=None)
# get_all_metrics_searcher(run_diy_folder, diy_qrels, path, s_name = "colbert")
# Out:
#                                                       nDCG@5  Judged@50  \
# tct-colbertv2+t5                                    0.734091     0.4256
# tct-colbertv2                                       0.706668     0.4256
# ance+t5                                             0.728414     0.3936
# ance                                                0.659857     0.3936
# bm25+best_k1=2.4+best_b=0.58                        0.612741     0.4522
# bm25+rm3+best_k1=2.4+best_b=0.58+best_fb_terms=...  0.620172     0.4506
# bm25+rm3+t5                                         0.711260     0.4446
# bm25+rm3                                            0.607062     0.4446
# bm25+t5                                             0.699732     0.4482
# bm25                                                0.603222     0.4482
# hybrid-tct-bm25+rm3+t5                              0.732370     0.4412
# marqo+t5                                            0.723273     0.4408
# marqo                                               0.591279     0.4408
#
#                                                         R@20      R@50  \
# tct-colbertv2+t5                                    0.639537  0.725548
# tct-colbertv2                                       0.581808  0.725548
# ance+t5                                             0.572088  0.634916
# ance                                                0.495682  0.634916
# bm25+best_k1=2.4+best_b=0.58                        0.602782  0.758041
# bm25+rm3+best_k1=2.4+best_b=0.58+best_fb_terms=...  0.614654  0.774383
# bm25+rm3+t5                                         0.657496  0.761038
# bm25+rm3                                            0.601300  0.761038
# bm25+t5                                             0.652576  0.746857
# bm25                                                0.583827  0.746857
# hybrid-tct-bm25+rm3+t5                              0.663994  0.755945
# marqo+t5                                            0.647655  0.731489
# marqo                                               0.525971  0.731489
#
#                                                     Judged@10    P@5  \
# tct-colbertv2+t5                                        1.000  0.806
# tct-colbertv2                                           1.000  0.776
# ance+t5                                                 1.000  0.798
# ance                                                    1.000  0.702
# bm25+best_k1=2.4+best_b=0.58                            0.949  0.702
# bm25+rm3+best_k1=2.4+best_b=0.58+best_fb_terms=...      0.956  0.720
# bm25+rm3+t5                                             1.000  0.782
# bm25+rm3                                                1.000  0.702
# bm25+t5                                                 1.000  0.768
# bm25                                                    1.000  0.692
# hybrid-tct-bm25+rm3+t5                                  0.998  0.810
# marqo+t5                                                0.998  0.796
# marqo                                                   0.999  0.668
#
#                                                           AP       P@3   P@10  \
# tct-colbertv2+t5                                    0.560575  0.840000  0.676
# tct-colbertv2                                       0.522006  0.836667  0.633
# ance+t5                                             0.501886  0.833333  0.648
# ance                                                0.431141  0.783333  0.559
# bm25+best_k1=2.4+best_b=0.58                        0.510474  0.730000  0.599
# bm25+rm3+best_k1=2.4+best_b=0.58+best_fb_terms=...  0.531828  0.756667  0.617
# bm25+rm3+t5                                         0.582288  0.810000  0.701
# bm25+rm3                                            0.517337  0.743333  0.617
# bm25+t5                                             0.566354  0.790000  0.684
# bm25                                                0.492949  0.730000  0.586
# hybrid-tct-bm25+rm3+t5                              0.580512  0.833333  0.682
# marqo+t5                                            0.562370  0.840000  0.675
# marqo                                               0.452799  0.713333  0.555
#
#                                                      nDCG@10      R@10  \
# tct-colbertv2+t5                                    0.710232  0.469800
# tct-colbertv2                                       0.668709  0.444352
# ance+t5                                             0.686521  0.447780
# ance                                                0.616760  0.384021
# bm25+best_k1=2.4+best_b=0.58                        0.598772  0.412469
# bm25+rm3+best_k1=2.4+best_b=0.58+best_fb_terms=...  0.611930  0.420909
# bm25+rm3+t5                                         0.706642  0.487495
# bm25+rm3                                            0.605838  0.422303
# bm25+t5                                             0.695584  0.475829
# bm25                                                0.584405  0.403740
# hybrid-tct-bm25+rm3+t5                              0.712247  0.474226
# marqo+t5                                            0.706699  0.470375
# marqo                                               0.573951  0.387691
#
#                                                     Judged@20    nDCG@3
# tct-colbertv2+t5                                       0.7930  0.743916
# tct-colbertv2                                          0.7415  0.747250
# ance+t5                                                0.7385  0.745780
# ance                                                   0.7000  0.712920
# bm25+best_k1=2.4+best_b=0.58                           0.7595  0.629118
# bm25+rm3+best_k1=2.4+best_b=0.58+best_fb_terms=...     0.7595  0.642568
# bm25+rm3+t5                                            0.7995  0.732631
# bm25+rm3                                               0.7655  0.629136
# bm25+t5                                                0.8075  0.720798
# bm25                                                   0.7725  0.624129
# hybrid-tct-bm25+rm3+t5                                 0.8085  0.736569
# marqo+t5                                               0.7870  0.745902
# marqo                                                  0.7395  0.617419

# %%
val = scipy.stats.ttest_ind(a = [0.1,0.2], b = [0.15,0.21])

statistic, pvalue = val
# Out:
# Ttest_indResult(statistic=-0.514495755427526, pvalue=0.6581182706210865)

# %%
"""Statistical Significance"""

import scipy
from ir_measures import *
from results_helper import get_metrics

metrics = [AP, nDCG@3, nDCG@10, P@3, P@10, R@50]

# def check_null_hyypothesis(run_diy_folder, diy_qrels, metric, )

ttest_results = {}
for metric in metrics:

    df = get_metrics(run_diy_folder, diy_qrels, metric, t5 = None)
    pivoted_df = df.pivot(index='query_id', columns='model', values='metric_val').reset_index()

    baseline = pivoted_df["bm25+best_k1=2"]
    # pivoted_df
    compared_models = [m_name for m_name in pivoted_df.columns] 
    compared_models.remove('query_id')
    compared_models.remove('bm25+best_k1=2')

    results_for_metric = {}
    for model_name in compared_models:
        value_metrics = pivoted_df[model_name]
        statistic, pvalue = scipy.stats.ttest_rel(a = value_metrics, b = baseline)
        results_for_metric[model_name] = pvalue
        # print(m_name, statistic, pvalue)
    ttest_results[metric] = results_for_metric


ttest_pd = pd.DataFrame(ttest_results)

# %%
ttest_pd < 0.05
# Out:
#                            AP  nDCG@3  nDCG@10    P@3   P@10   R@50
# TCT-ColBERTv2           False    True     True   True  False  False
# TCT-ColBERTv2+t5         True    True     True   True   True  False
# ance                     True    True    False  False  False   True
# ance+t5                 False    True     True   True   True   True
# bm25                     True   False    False  False  False  False
# bm25+rm3                False   False    False  False  False  False
# bm25+rm3+best_k1=2       True   False    False  False   True   True
# bm25+rm3+t5              True    True     True   True   True  False
# bm25+t5                  True    True     True   True   True  False
# hybrid-tct-bm25+rm3+t5   True    True     True   True   True  False
# marqo                    True   False    False  False   True  False
# marqo+t5                 True    True     True   True   True  False

# %% [markdown]
# ### Precision Recall Graph

# %%
from results_helper import get_precision_recall_graph

diy_qrels = os.path.join(qrels_folder, "diy.qrels")

get_precision_recall_graph(run_diy_folder, diy_qrels, with_t5 = True)

# %% [markdown]
# ### Query by query Analysis

# %%
diy_runs = os.listdir(run_diy_folder)
diy_qrels = os.path.join(qrels_folder, "diy.qrels")

judgments = []
with open(diy_qrels, "r") as f:
    for j in f:
        judgment = j.strip().split(" ")
        judgment[3] = int(judgment[3])
        judgments.append(judgment)

diy_pd = pd.DataFrame(judgments, columns = ['qid', 'run', 'docid', "score"])

diy_pd.head()
stats_pd = diy_pd.groupby(by=["qid"])["score"].agg(['count', 'mean', 'std']).reset_index()
stats_pd["id"] = stats_pd["qid"].str.replace("query-", "").astype(int)
stats_pd = stats_pd.sort_values(by=['id'])
stats_pd.head()
# Out:
#         qid  count      mean       std  id
# 0   query-0     91  0.505495  0.689180   0
# 1   query-1     55  0.763636  0.719147   1
# 12  query-2     44  0.545455  0.663134   2
# 23  query-3     34  0.558824  0.704581   3
# 34  query-4     70  0.500000  0.717282   4

# %%
import matplotlib.pyplot as plt

colors = ['red', 'green', 'blue', 'black', 'pink', 'purple', 'orange', 'yellow', 'cyan', 'brown']



# print(len( df["model"].unique()))
# df = pd.read_csv("/home/ubuntu/task-search-quality/measurements/diy/analysis/diy-MAP-best.csv")
# df.head()
# for model_name, color in zip(df["model"].unique(), colors):
#     points_to_plot = df[df["model"] == model_name]
#     # print(len(points_to_plot))
#     filtered_df = stats_pd[stats_pd["qid"].isin(points_to_plot['query_id'])]
#     # print(len(filtered_df))
#     # print(filtered_df)
 
plt.errorbar(x=stats_pd.index, y=stats_pd["mean"], yerr=stats_pd["std"], fmt='o')
plt.title("Means and Standard Deviations for judgments regarding DIY Queries")

plt.xlabel('Query IDs')
plt.ylabel('Value spread across judgments')
plt.grid(linestyle='--')
plt.xlim(-1,101)
plt.ylim(-0.5)
plt.show()

# %%
# diy_queries.head()

# %% [markdown]
# ### Get metrics per query / separate by t5-non-t5

# %%
from results_helper import get_metrics, get_raw_query
from ir_measures import *  

queries = pd.read_csv("/home/ubuntu/task-search-quality/queries/diy.csv")  

t5_vals = [False, True]
for t5 in t5_vals:
    ap_vals = get_metrics(run_diy_folder, diy_qrels, AP, t5)
    recall_vals = get_metrics(run_diy_folder, diy_qrels, Recall@50, t5)
    ndcg_vals = get_metrics(run_diy_folder, diy_qrels, nDCG@10, t5)
    ndcg_vals3 = get_metrics(run_diy_folder, diy_qrels, nDCG@3, t5)
    ndcg_vals5 = get_metrics(run_diy_folder, diy_qrels, nDCG@5, t5)
    

    results = {}
    results["DIY"] = {
        "MAP": ap_vals,
        "Recall@50": recall_vals,
        "Ndgc@10": ndcg_vals,
        "Ndgc@3": ndcg_vals3,
        "Ndgc@5": ndcg_vals5,
    }

    analysis_folder = "/home/ubuntu/task-search-quality/measurements/diy/analysis"
    
    if t5:
        analysis_folder += "/t5-results"
    else:
        analysis_folder += "/non-t5-results"

    for metric, df in results["DIY"].items():
        pivoted_df = df.pivot(index='query_id', columns='model', values='metric_val').reset_index()
        pivoted_df["query"] = pivoted_df.apply(lambda x: get_raw_query(x, queries), axis=1)
        pivoted_df.to_csv(os.path.join(analysis_folder, metric+".csv"), index=False)

pivoted_df.head()
# Out:
# model  query_id  TCT-ColBERTv2+t5   ance+t5  bm25+rm3+t5   bm25+t5  marqo+t5  \
# 0       query-0          0.425485  0.425485     0.563261  0.563261  0.509961
# 1       query-1          0.710971  0.710971     0.691783  0.691783  0.710971
# 2      query-10          0.786014  0.786014     0.830420  0.853932  0.934397
# 3      query-11          0.819973  0.827404     0.657824  0.584790  0.819973
# 4      query-12          0.592222  0.000000     0.550831  0.550831  0.681336
#
# model                                   query
# 0      how to choose a good hairstyle for men
# 1                 how to learn a new language
# 2                     how to style curly hair
# 3               how to write a biography book
# 4                          how to grow apples

# %% [markdown]
# ### Graph Box Plots for MAP, nDCG@10, Recall@50

# %%
import seaborn as sns
import matplotlib.pyplot as plt

analysis_folder = "/home/ubuntu/task-search-quality/measurements/diy/analysis/non-t5-results"

files = os.listdir(analysis_folder)

for file in files:
    
    # print(file)
    filepath = os.path.join(analysis_folder, file)
    df = pd.read_csv(filepath) # index_col="query_id"
    df["mean"] = df.mean(axis=1, numeric_only=True)
    df = df.sort_values(by=["mean"], ascending=True)
    # print(df.columns)
    df_T = df[df.columns[1:-2]].T
    # print(df_T)
    sns.boxplot(data=df_T)
    
    y_label = file.split(".")[0]
    
    plt.title(f"{y_label} per query")
    plt.ylabel(y_label)
    plt.xlabel("queries")
    plt.xticks([])
    plt.show()

df.head()
# Out:
#     query_id  TCT-ColBERTv2      ance      bm25  bm25+rm3     marqo  \
# 89   query-9       0.302656  0.344783  0.000000  0.000000  0.183110
# 75  query-77       0.388077  0.165802  0.207393  0.000000  0.473636
# 40  query-45       0.168427  0.636005  0.393939  0.330255  0.236746
# 58  query-61       0.819244  0.098154  0.243689  0.039826  0.631811
# 3   query-11       0.489555  0.563070  0.241262  0.180261  0.400220
#
#                             query      mean
# 89         how can I screw a nail  0.166110
# 75     how to wash a newborn baby  0.246982
# 40    how to warm up before a run  0.353074
# 58          how to make a coaster  0.366545
# 3   how to write a biography book  0.374874

# %% [markdown]
# ### Difficult queries performance

# %%
analysis_folder = "/home/ubuntu/task-search-quality/measurements/diy/analysis/non-t5-results"

files = os.listdir(analysis_folder)

results = {}

thresholds = [5,10, 15,20]

for threshold in thresholds:
    for file in files:
        
        # print(file)
        if "Recall" in file:
            continue
        filepath = os.path.join(analysis_folder, file)
        df = pd.read_csv(filepath) # index_col="query_id"
        df["mean"] = df.mean(axis=1, numeric_only=True)
        df = df.sort_values(by=["mean"], ascending=True)
        hardest_10 = df.head(threshold)
        hardest_10 = hardest_10.drop(columns = ["query_id", "query"])
        hardest_10.mean()
        results[(threshold, file.split('.')[0])] = hardest_10.mean()
# Out:
# nDCG@5.csv
# TCT-ColBERTv2    0.414507
# ance             0.300100
# bm25             0.187031
# bm25+rm3         0.097374
# marqo            0.290110
# mean             0.257824
# dtype: float64
# MAP.csv
# TCT-ColBERTv2    0.260246
# ance             0.294699
# bm25             0.125380
# bm25+rm3         0.108340
# marqo            0.201310
# mean             0.197995
# dtype: float64
# nDCG@3.csv
# TCT-ColBERTv2    0.320531
# ance             0.276443
# bm25             0.182773
# bm25+rm3         0.046928
# marqo            0.446928
# mean             0.254721
# dtype: float64
# nDCG@10.csv
# TCT-ColBERTv2    0.433592
# ance             0.361563
# bm25             0.217257
# bm25+rm3         0.110068
# marqo            0.385105
# mean             0.301517
# dtype: float64
# nDCG@5.csv
# TCT-ColBERTv2    0.452697
# ance             0.363691
# bm25             0.257496
# bm25+rm3         0.170321
# marqo            0.330864
# mean             0.315014
# dtype: float64
# MAP.csv
# TCT-ColBERTv2    0.295641
# ance             0.284265
# bm25             0.178387
# bm25+rm3         0.197663
# marqo            0.179112
# mean             0.227014
# dtype: float64
# nDCG@3.csv
# TCT-ColBERTv2    0.418109
# ance             0.386347
# bm25             0.222601
# bm25+rm3         0.133135
# marqo            0.379701
# mean             0.307979
# dtype: float64
# nDCG@10.csv
# TCT-ColBERTv2    0.457260
# ance             0.455455
# bm25             0.290700
# bm25+rm3         0.240846
# marqo            0.333738
# mean             0.355600
# dtype: float64
# nDCG@5.csv
# TCT-ColBERTv2    0.454370
# ance             0.421601
# bm25             0.315288
# bm25+rm3         0.246474
# marqo            0.360592
# mean             0.359665
# dtype: float64
# MAP.csv
# TCT-ColBERTv2    0.336478
# ance             0.285579
# bm25             0.235673
# bm25+rm3         0.239281
# marqo            0.175538
# mean             0.254510
# dtype: float64
# nDCG@3.csv
# TCT-ColBERTv2    0.434163
# ance             0.488516
# bm25             0.249743
# bm25+rm3         0.184295
# marqo            0.388819
# mean             0.349107
# dtype: float64
# nDCG@10.csv
# TCT-ColBERTv2    0.477584
# ance             0.429266
# bm25             0.362456
# bm25+rm3         0.315408
# marqo            0.319498
# mean             0.380842
# dtype: float64
# nDCG@5.csv
# TCT-ColBERTv2    0.475281
# ance             0.525820
# bm25             0.328659
# bm25+rm3         0.268294
# marqo            0.344306
# mean             0.388472
# dtype: float64
# MAP.csv
# TCT-ColBERTv2    0.343730
# ance             0.291060
# bm25             0.259207
# bm25+rm3         0.269329
# marqo            0.212569
# mean             0.275179
# dtype: float64
# nDCG@3.csv
# TCT-ColBERTv2    0.487354
# ance             0.556191
# bm25             0.303369
# bm25+rm3         0.226490
# marqo            0.352088
# mean             0.385098
# dtype: float64
# nDCG@10.csv
# TCT-ColBERTv2    0.507454
# ance             0.465315
# bm25             0.373349
# bm25+rm3         0.339463
# marqo            0.339886
# mean             0.405093
# dtype: float64

# %%
res = []
for threshold, vals in results.items():
        res.append({
            "metric": threshold[1],
            "threshold": threshold[0],
            "BM25": vals["bm25"],       
            "BM25+RM3": vals["bm25+rm3"],      
            "TCT-ColBERT v2": vals["TCT-ColBERTv2"], 
            "ANCE": vals["ance"],   
            "MiniLM-6": vals["marqo"],             
        })
df_hardest = pd.DataFrame(res)
df_hardest.sort_values(by="metric", inplace=True)
df_hardest.head()


import matplotlib.pyplot as plt

for metric in df_hardest["metric"].unique():
    df = df_hardest[df_hardest["metric"] == metric]
    # set the plot style
    plt.style.use('seaborn-darkgrid')
    # plot the line plot
    for model in df.columns[2:]:
        plt.plot(df["threshold"], df[model], label=model)

    plt.xticks([5, 10, 15, 20])
    plt.ylabel("Average nDCG@10 across the top-N queries")
    plt.xlabel("Number of Most Difficult Queries (N)")
    # set the title
    plt.title("Average Performance of DIY Queries with Lowest Retrieval Scores")
    # add the legend
    plt.legend()
    # show the plot
    plt.show()
# Out:
# /tmp/ipykernel_7112/885776774.py:22: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# /tmp/ipykernel_7112/885776774.py:22: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# /tmp/ipykernel_7112/885776774.py:22: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# /tmp/ipykernel_7112/885776774.py:22: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ### Easy queries performance

# %%
analysis_folder = "/home/ubuntu/task-search-quality/measurements/diy/analysis/non-t5-results"

files = os.listdir(analysis_folder)

results = {}

# thresholds = range(1,21)
thresholds = [5,10,15,20]

for threshold in thresholds:
    for file in files:
        
        # print(file)
        if "Recall" in file:
            continue
        filepath = os.path.join(analysis_folder, file)
        df = pd.read_csv(filepath) # index_col="query_id"
        df["mean"] = df.mean(axis=1, numeric_only=True)
        df = df.sort_values(by=["mean"], ascending=True)
        easiest = df.tail(threshold)
        easiest = easiest.drop(columns = ["query_id", "query"])
        easiest.mean()
        results[(threshold, file.split('.')[0])] = easiest.mean()

# %%
res = []
for threshold, vals in results.items():
        res.append({
            "metric": threshold[1],
            "threshold": threshold[0],
            "BM25": vals["bm25"],       
            "BM25+RM3": vals["bm25+rm3"],      
            "TCT-ColBERT v2": vals["TCT-ColBERTv2"], 
            "ANCE": vals["ance"],   
            "MiniLM-6": vals["marqo"],          
        })
df_hardest = pd.DataFrame(res)
df_hardest.sort_values(by="metric", inplace=True)
df_hardest.head()


import matplotlib.pyplot as plt

for metric in df_hardest["metric"].unique():
    df = df_hardest[df_hardest["metric"] == metric]
    # set the plot style
    plt.style.use('seaborn-darkgrid')
    # plot the line plot
    for model in df.columns[2:]:
        plt.plot(df["threshold"], df[model], label=model)

    plt.xticks([5, 10, 15, 20])
    plt.ylabel("Average nDCG@10 across the top-N queries")
    plt.xlabel("Number of Easiest Queries (N)")
    # set the title
    plt.title("Average Performance of DIY Queries with Highest Retrieval Scores")
    # add the legend
    plt.legend()
    # show the plot
    plt.show()
# Out:
# /tmp/ipykernel_760111/3312905535.py:22: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# /tmp/ipykernel_760111/3312905535.py:22: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# /tmp/ipykernel_760111/3312905535.py:22: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# /tmp/ipykernel_760111/3312905535.py:22: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
analysis_folder = "/home/ubuntu/task-search-quality/measurements/diy/analysis/non-t5-results"

files = os.listdir(analysis_folder)
results = {}

for file in files:
    if "Recall" not in file:
        continue
    print(file)
    filepath = os.path.join(analysis_folder, file)
    df = pd.read_csv(filepath)
    df["std"] = df.std(axis=1, numeric_only=True)
    df = df.sort_values(by=["std"], ascending=False)
df.head()
# Out:
# Recall@50.csv
#     query_id  TCT-ColBERTv2      ance      bm25  bm25+rm3     marqo  \
# 58  query-61       1.000000  0.250000  1.000000  1.000000  1.000000
# 73  query-75       0.818182  1.000000  0.363636  0.363636  0.818182
# 49  query-53       0.900000  0.400000  0.950000  1.000000  0.450000
# 57  query-60       0.904762  0.333333  0.952381  0.952381  1.000000
# 0    query-0       0.684211  0.736842  0.578947  0.578947  0.052632
#
#                                      query       std
# 58                   how to make a coaster  0.335410
# 73          how to build a gaming computer  0.291760
# 49                 how to put up wallpaper  0.290259
# 57              how to make napkin designs  0.278887
# 0   how to choose a good hairstyle for men  0.273482

# %% [markdown]
# #### Comparison between TCT-Colbert_v2 vs TCT-Colbert_v2+t5 vs BM25+RM3+T5

# %%
df = get_all_metrics(run_diy_folder, diy_qrels, path, with_t5=None)
df.loc[["tct-colbertv2", "tct-colbertv2+t5", 'bm25+rm3+t5']]
# Out:
#                   Judged@10       P@3   P@10  Judged@50   nDCG@10        AP  \
# tct-colbertv2           1.0  0.833333  0.632     0.4196  0.669332  0.529378
# tct-colbertv2+t5        1.0  0.836667  0.675     0.4196  0.710087  0.568235
# bm25+rm3+t5             1.0  0.806667  0.699     0.4352  0.706960  0.587040
#
#                     nDCG@5    P@5    nDCG@3      R@20      R@50      R@10  \
# tct-colbertv2     0.706039  0.774  0.746081  0.594048  0.735527  0.453904
# tct-colbertv2+t5  0.730889  0.804  0.740442  0.649272  0.735527  0.480994
# bm25+rm3+t5       0.709245  0.780  0.729661  0.666616  0.767079  0.498971
#
#                   Judged@20
# tct-colbertv2        0.7390
# tct-colbertv2+t5     0.7855
# bm25+rm3+t5          0.7905

# %%
paths = []
paths.append("/home/ubuntu/task-search-quality/measurements/diy/analysis/non-t5-results/nDCG@3.csv")
paths.append("/home/ubuntu/task-search-quality/measurements/diy/analysis/t5-results/nDCG@3.csv")
print(paths)
df1 = pd.read_csv(paths[0])
df2 = pd.read_csv(paths[1])
df2.drop(columns=["query"], inplace=True)
# print(df1.columns)
df = pd.merge(
    df1, df2,
    on=["query_id"]
)
df = df[["query_id","query", "TCT-ColBERTv2", "TCT-ColBERTv2+t5", "bm25+rm3+t5"]].sort_values(by=["TCT-ColBERTv2"])

df.head()
# Out:
# ['/home/ubuntu/task-search-quality/measurements/diy/analysis/non-t5-results/nDCG@3.csv', '/home/ubuntu/task-search-quality/measurements/diy/analysis/t5-results/nDCG@3.csv']
#     query_id                                 query  TCT-ColBERTv2  \
# 11  query-19     how to wash a stainless steel pan       0.000000
# 59  query-62           how to draw a birthday card       0.234639
# 75  query-77            how to wash a newborn baby       0.234639
# 76  query-78  how to train a dog to behave outside       0.234639
# 89   query-9                how can I screw a nail       0.234639
#
#     TCT-ColBERTv2+t5  bm25+rm3+t5
# 11          0.586598     0.234639
# 59          0.000000     0.000000
# 75          0.469279     0.765361
# 76          0.648041     0.413402
# 89          0.586598     0.469279

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


df["bm25+rm3+t5_dif"] = df["TCT-ColBERTv2"] - df["bm25+rm3+t5"]
df["TCT-ColBERTv2+t5_dif"] = df["TCT-ColBERTv2"] - df["TCT-ColBERTv2+t5"]

df.sort_values(by=["TCT-ColBERTv2+t5_dif"], inplace=True)

# Plot the dots for each column using relplot
sns.relplot(x='query_id', y='value', kind='scatter', hue='variable', data=pd.melt(df[["query_id", "TCT-ColBERTv2+t5_dif", "bm25+rm3+t5_dif"]], id_vars='query_id'))

# Add labels to the x and y axes
plt.xlabel("Query ID")
plt.ylabel("NDGC@3 Value")
plt.xticks([])
plt.style.use('seaborn-darkgrid')
plt.legend(title="Search Algorithm")
plt.show()
# Out:
# /tmp/ipykernel_597796/1993930768.py:19: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
df.head()
# Out:
#     query_id                                  query  TCT-ColBERTv2  \
# 11  query-19      how to wash a stainless steel pan       0.000000
# 54  query-58  how to make a candles that smell well       0.382680
# 26  query-32              paint nails with patterns       0.500000
# 22  query-29                    paint a metal fence       0.586598
# 76  query-78   how to train a dog to behave outside       0.234639
#
#     TCT-ColBERTv2+t5  bm25+rm3+t5  bm25+rm3+t5_dif  TCT-ColBERTv2+t5_dif
# 11          0.586598     0.234639        -0.234639             -0.586598
# 54          0.882680     0.648041        -0.265361             -0.500000
# 26          1.000000     1.000000        -0.500000             -0.500000
# 22          1.000000     0.882680        -0.296082             -0.413402
# 76          0.648041     0.413402        -0.178762             -0.413402

# %%
df.tail()
# Out:
#     query_id                           query  TCT-ColBERTv2  TCT-ColBERTv2+t5  \
# 87  query-88              how to catch a fly       1.000000          0.530721
# 90  query-90    how to make an asian lantern       1.000000          0.469279
# 34   query-4     how do I decorate an office       1.000000          0.469279
# 43  query-48  how to change a child's diaper       0.851959          0.265361
# 24  query-30     create an outdoor fireplace       1.000000          0.234639
#
#     bm25+rm3+t5  bm25+rm3+t5_dif  TCT-ColBERTv2+t5_dif
# 87     0.765361         0.234639              0.469279
# 90     0.586598         0.413402              0.530721
# 34     0.617320         0.382680              0.530721
# 43     0.296082         0.555877              0.586598
# 24     0.530721         0.469279              0.765361

# %%
df.sort_values(by=["bm25+rm3+t5_dif"], inplace=True)
df.head()
# Out:
#     query_id                            query  TCT-ColBERTv2  \
# 75  query-77       how to wash a newborn baby       0.234639
# 26  query-32        paint nails with patterns       0.500000
# 66  query-69  how to make christmas ornaments       0.530721
# 55  query-59     how to build a toy for a pet       0.296082
# 96  query-96         how to fix a door handle       0.398739
#
#     TCT-ColBERTv2+t5  bm25+rm3+t5  bm25+rm3+t5_dif  TCT-ColBERTv2+t5_dif
# 75          0.469279     0.765361        -0.530721             -0.234639
# 26          1.000000     1.000000        -0.500000             -0.500000
# 66          0.851959     1.000000        -0.469279             -0.321238
# 55          0.703918     0.765361        -0.469279             -0.407836
# 96          0.797478     0.867087        -0.468348             -0.398739

# %%
df.tail()
# Out:
#     query_id                           query  TCT-ColBERTv2  TCT-ColBERTv2+t5  \
# 44  query-49       how to make a bubble bath       0.882680          1.000000
# 24  query-30     create an outdoor fireplace       1.000000          0.234639
# 78   query-8       how do I clean the fridge       0.703918          0.413402
# 43  query-48  how to change a child's diaper       0.851959          0.265361
# 63  query-66            how to make stickers       0.664565          0.265826
#
#     bm25+rm3+t5  bm25+rm3+t5_dif  TCT-ColBERTv2+t5_dif
# 44     0.413402         0.469279             -0.117320
# 24     0.530721         0.469279              0.765361
# 78     0.148041         0.555877              0.290516
# 43     0.296082         0.555877              0.586598
# 63     0.000000         0.664565              0.398739

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

paths = []
paths.append("./measurements/diy/analysis/non-t5-results/nDCG@5.csv")
paths.append("./measurements/diy/analysis/t5-results/nDCG@5.csv")
print(paths)
df1 = pd.read_csv(paths[0])
df2 = pd.read_csv(paths[1])
df2.drop(columns=["query"], inplace=True)
# print(df1.columns)
df = pd.merge(
    df1, df2,
    on=["query_id"]
)
df = df[["query_id","query", "TCT-ColBERTv2", "TCT-ColBERTv2+t5", "bm25+rm3+t5"]].sort_values(by=["TCT-ColBERTv2"])


df["bm25+rm3+t5_dif"] = df["TCT-ColBERTv2"] - df["bm25+rm3+t5"]
df["TCT-ColBERTv2+t5_dif"] = df["TCT-ColBERTv2"] - df["TCT-ColBERTv2+t5"]

df.sort_values(by=["TCT-ColBERTv2+t5_dif"], inplace=True)
# df = df[["query_id", "TCT-ColBERTv2+t5_dif", "bm25+rm3+t5_dif"]]

# Plot the dots for each column using relplot
sns.relplot(x='query_id', y='value', kind='scatter', hue='variable', data=pd.melt(df[["query_id", "TCT-ColBERTv2+t5_dif", "bm25+rm3+t5_dif"]], id_vars='query_id'))

# Add labels to the x and y axes
plt.xlabel("Query ID")
plt.ylabel("NDGC@5 Value")
plt.xticks([])
plt.style.use('seaborn-darkgrid')
plt.legend(title="Search Algorithm")
plt.show()
# Out:
# ['/home/ubuntu/task-search-quality/measurements/diy/analysis/non-t5-results/nDCG@5.csv', '/home/ubuntu/task-search-quality/measurements/diy/analysis/t5-results/nDCG@5.csv']
# /tmp/ipykernel_597796/3287895752.py:33: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
df.head()
# Out:
#     query_id                              query  TCT-ColBERTv2  \
# 11  query-19  how to wash a stainless steel pan       0.065603
# 32  query-38                 how to gain muscle       0.446153
# 26  query-32          paint nails with patterns       0.500000
# 42  query-47  how to install a sprinkler system       0.568346
# 66  query-69    how to make christmas ornaments       0.529635
#
#     TCT-ColBERTv2+t5  bm25+rm3+t5  bm25+rm3+t5_dif  TCT-ColBERTv2+t5_dif
# 11          0.570019     0.446854        -0.381251             -0.504416
# 32          0.915210     1.000000        -0.553847             -0.469057
# 26          0.934397     1.000000        -0.500000             -0.434397
# 42          0.977724     0.910191        -0.341844             -0.409378
# 66          0.893007     0.795761        -0.266126             -0.363372

# %%
df.tail()
# Out:
#     query_id                                  query  TCT-ColBERTv2  \
# 79  query-80  how to make a professional book cover       0.819973
# 34   query-4            how do I decorate an office       1.000000
# 72  query-74                 how to cut my own hair       1.000000
# 24  query-30            create an outdoor fireplace       0.795761
# 63  query-66                   how to make stickers       0.808925
#
#     TCT-ColBERTv2+t5  bm25+rm3+t5  bm25+rm3+t5_dif  TCT-ColBERTv2+t5_dif
# 79          0.404763     0.710971         0.109002              0.415210
# 34          0.550831     0.723427         0.276573              0.449169
# 72          0.514771     0.529635         0.470365              0.485229
# 24          0.242614     0.587806         0.207955              0.553146
# 63          0.218370     0.168954         0.639971              0.590555

# %%
df.sort_values(by=["bm25+rm3+t5_dif"], inplace=True)
df.head()
# Out:
#     query_id                              query  TCT-ColBERTv2  \
# 32  query-38                 how to gain muscle       0.446153
# 75  query-77         how to wash a newborn baby       0.196874
# 26  query-32          paint nails with patterns       0.500000
# 55  query-59       how to build a toy for a pet       0.418226
# 11  query-19  how to wash a stainless steel pan       0.065603
#
#     TCT-ColBERTv2+t5  bm25+rm3+t5  bm25+rm3+t5_dif  TCT-ColBERTv2+t5_dif
# 32          0.915210     1.000000        -0.553847             -0.469057
# 75          0.546071     0.726965        -0.530091             -0.349197
# 26          0.934397     1.000000        -0.500000             -0.434397
# 55          0.639945     0.830420        -0.412194             -0.221720
# 11          0.570019     0.446854        -0.381251             -0.504416

# %%
df.tail()
# Out:
#     query_id                              query  TCT-ColBERTv2  \
# 64  query-67  how to make my own fridge magnets       0.926966
# 59  query-62        how to draw a birthday card       0.446854
# 43  query-48     how to change a child's diaper       0.746939
# 72  query-74             how to cut my own hair       1.000000
# 63  query-66               how to make stickers       0.808925
#
#     TCT-ColBERTv2+t5  bm25+rm3+t5  bm25+rm3+t5_dif  TCT-ColBERTv2+t5_dif
# 64          0.868795     0.514771         0.412194              0.058171
# 59          0.277273     0.000000         0.446854              0.169580
# 43          0.469057     0.279589         0.467350              0.277882
# 72          0.514771     0.529635         0.470365              0.485229
# 63          0.218370     0.168954         0.639971              0.590555

# %% [markdown]
# #### How nDCG@n changes with increasing n

# %%
from results_helper import get_nDGCs_per_run

ndgc_folder = "/home/ubuntu/task-search-quality/measurements/diy/analysis/nDCG-comparison"
diy_qrels = os.path.join(qrels_folder, "diy.qrels")
run_diy_folder = os.path.join(os.getcwd(), 'measurements', 'diy', 'run_files')
runs = ['TCT-ColBERTv2.run', 'TCT-ColBERTv2+t5.run' , 'bm25+rm3+t5.run']

results = {}
for run in runs:
    run_path = os.path.join(run_diy_folder, run)
    ndgcs = get_nDGCs_per_run(run_path, diy_qrels)
    results[run.split('.')[0]] = ndgcs
df = pd.DataFrame(results)
print(df.index)

df.index = [int(str(i).split("@")[1]) for i in df.index]
df.sort_index(inplace=True)
print(df)

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

sns.lineplot(data=df, dashes=False, linewidth=2, markers=True,)
plt.style.use('seaborn-darkgrid')

# Add labels to the x and y axes
plt.xlabel("n")
plt.ylabel("nDCG score")

# Add a legend
plt.legend(title="nDCG change with parameter n")

# Show the plot
plt.show()
# Out:
# Index([nDCG@7, nDCG@10, nDCG@1, nDCG@9, nDCG@5, nDCG@6, nDCG@3, nDCG@2, nDCG@4,
#        nDCG@8],
#       dtype='object')
#     TCT-ColBERTv2  TCT-ColBERTv2+t5  bm25+rm3+t5
# 1        0.860000          0.805000     0.805000
# 2        0.772494          0.754245     0.767785
# 3        0.746081          0.740442     0.729661
# 4        0.719198          0.732120     0.720841
# 5        0.706039          0.730889     0.709245
# 6        0.695480          0.729946     0.702986
# 7        0.686986          0.719657     0.700871
# 8        0.673594          0.715038     0.695766
# 9        0.671849          0.710505     0.702882
# 10       0.669332          0.710087     0.706960
# /tmp/ipykernel_760111/3978367736.py:25: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ### Analysis of different task representations

# %%
from ir_measures import *

path_marqo_runs = "/home/ubuntu/task-search-quality/measurements/diy/run_files/marqo-filters"
diy_qrels = "/home/ubuntu/task-search-quality/measurements/judgments/diy-all.qrels"


metrics = [nDCG@5, nDCG@10, Precision@3, Precision@5, Precision@10, Recall@5, Recall@10,  Recall@50, Judged@10, MAP]

# %%
from results_helper import get_all_metrics

path = "/home/ubuntu/task-search-quality/measurements/diy/analysis/marqo-filters"

get_all_metrics(path_marqo_runs, diy_qrels, path, with_t5=None, metrics=metrics)
# Out:
#                    P@10    nDCG@5   nDCG@10        AP       R@5    P@5  \
# steps-title       0.635  0.721788  0.682918  0.558847  0.278710  0.776
# steps             0.394  0.400103  0.393767  0.279401  0.176091  0.482
# tags-steps-title  0.636  0.722438  0.684181  0.560961  0.278122  0.774
# tags-steps        0.408  0.406368  0.403636  0.292244  0.179257  0.490
# title-tags        0.651  0.741710  0.702755  0.570557  0.285772  0.798
# title             0.651  0.741273  0.703411  0.570692  0.286500  0.800
#
#                       R@10      R@50  Judged@10       P@3
# steps-title       0.443929  0.783753      0.923  0.863333
# steps             0.283124  0.550852      0.787  0.520000
# tags-steps-title  0.445200  0.785927      0.922  0.863333
# tags-steps        0.292424  0.577113      0.792  0.516667
# title-tags        0.454282  0.789865      0.890  0.873333
# title             0.453600  0.789451      0.892  0.873333

# %% [markdown]
# #### Notes:
# - title + tags and title alone perform best with almost no differences
# - steps + title and steps + title + tags with a close second
# - steps alone or steps + tags not performing well

# %%
from results_helper import get_metrics, get_raw_query
from ir_measures import *  

queries = pd.read_csv("/home/ubuntu/task-search-quality/queries/diy.csv")  
diy_qrels = "/home/ubuntu/task-search-quality/measurements/judgments/diy-all.qrels"

ap_vals = get_metrics(path_marqo_runs, diy_qrels, AP, t5=False)
ndcg_vals = get_metrics(path_marqo_runs, diy_qrels, nDCG@10, t5=False)



results = {}
results["DIY"] = {
    "Ndgc@10": ndcg_vals,
    "MAP": ap_vals,
}

analysis_folder = "/home/ubuntu/task-search-quality/measurements/diy/analysis/marqo-filters"


for metric, df in results["DIY"].items():
    pivoted_df = df.pivot(index='query_id', columns='model', values='metric_val').reset_index()
    pivoted_df["query"] = pivoted_df.apply(lambda x: get_raw_query(x, queries), axis=1)
    pivoted_df.to_csv(os.path.join(analysis_folder, metric+".csv"), index=False)

pivoted_df.head()
# Out:
# model  query_id     Steps  Steps-Title  Tags-Steps  Tags-Steps-Title  \
# 0       query-0  0.016249     0.414054    0.251642          0.559624
# 1       query-1  0.140140     0.400907    0.140140          0.400907
# 2      query-10  0.111596     0.345972    0.214894          0.345972
# 3      query-11  0.026136     0.369448    0.066503          0.369448
# 4      query-12  0.019780     0.239510    0.019780          0.239510
#
# model     Title  Title-Tags                                   query
# 0      0.561689    0.652175  how to choose a good hairstyle for men
# 1      0.391162    0.391162             how to learn a new language
# 2      0.319106    0.319106                 how to style curly hair
# 3      0.432286    0.432286           how to write a biography book
# 4      0.256777    0.256777                      how to grow apples

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

paths = []
paths.append("/home/ubuntu/task-search-quality/measurements/diy/analysis/marqo-filters/Ndgc@10.csv")
paths.append("/home/ubuntu/task-search-quality/measurements/diy/analysis/marqo-filters/MAP.csv")
print(paths)
df = pd.read_csv(paths[0])
# df2 = pd.read_csv(paths[1])

print(df.columns)

df.sort_values(by=["Title"], inplace=True)

# Plot the dots for each column using relplot
sns.relplot(x='query_id', y='value', kind='scatter', hue='variable', data=pd.melt(df[["query_id", "Title", "Steps-Title"]], id_vars='query_id'))

# Add labels to the x and y axes
plt.xlabel("Query ID")
plt.ylabel("NDGC@10 Value")
plt.xticks([])
plt.style.use('seaborn-darkgrid')
plt.legend(title="Search Algorithm")
plt.show()
# Out:
# ['/home/ubuntu/task-search-quality/measurements/diy/analysis/marqo-filters/Ndgc@10.csv', '/home/ubuntu/task-search-quality/measurements/diy/analysis/marqo-filters/MAP.csv']
# Index(['query_id', 'Steps', 'Steps-Title', 'Tags-Steps', 'Tags-Steps-Title',
#        'Title', 'Title-Tags', 'query'],
#       dtype='object')
# /tmp/ipykernel_2306/578784604.py:23: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
df["t vs t+s"] = df["Title"] - df["Steps-Title"]
df.sort_values(by=["t vs t+s"], inplace=True)
df.head()
# Title+Steps better
# Out:
#     query_id     Steps  Steps-Title  Tags-Steps  Tags-Steps-Title     Title  \
# 87  query-88  0.856560     0.962873    0.856560          0.962873  0.764644
# 57  query-60  0.609957     0.578087    0.609957          0.578087  0.407735
# 9   query-17  0.555579     0.703464    0.555579          0.703464  0.566505
# 44  query-49  0.512259     0.794995    0.512259          0.794995  0.687336
# 89   query-9  0.232044     0.241010    0.232044          0.241010  0.140743
#
#     Title-Tags                        query  t vs t+s
# 87    0.764644           how to catch a fly -0.198229
# 57    0.407735   how to make napkin designs -0.170353
# 9     0.566505  how to wash a cutting board -0.136960
# 44    0.687336    how to make a bubble bath -0.107659
# 89    0.140743       how can I screw a nail -0.100267

# %%
# Title better
df.tail()
# Out:
#     query_id     Steps  Steps-Title  Tags-Steps  Tags-Steps-Title     Title  \
# 32  query-38  0.197897     0.724255    0.197897          0.724255  0.884920
# 82  query-83  0.416550     0.379875    0.416550          0.379875  0.567255
# 40  query-45  0.054876     0.207900    0.054876          0.207900  0.428266
# 93  query-93  0.280905     0.423112    0.280905          0.423112  0.688878
# 18  query-25  0.390084     0.511519    0.390084          0.511519  0.896237
#
#     Title-Tags                               query  t vs t+s
# 32    0.884920                  how to gain muscle  0.160665
# 82    0.567255  how to make a paper fortune teller  0.187380
# 40    0.428266         how to warm up before a run  0.220365
# 93    0.688878            how to motivate my child  0.265766
# 18    0.896237            chop an onion like a pro  0.384718

# %%
threshold = 0.1
df = df

plt.barh(df['query_id'] + ' - 'df['query'], df['t vs t+s'])
# Out:
# <BarContainer object of 100 artists>
