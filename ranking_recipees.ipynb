# %%
import os
import sys

sys.path.insert(0, './compiled_protobufs')

# %%
dataset_names = ["recipe1mln"]
dataset_paths = [os.path.join(os.getcwd(), "bin", dataset, "taskmap") for dataset in dataset_names]

# %% [markdown]
# ## Loading queries

# %%
## Load queries
import pandas as pd 
from sklearn.model_selection import train_test_split
    
# import queries 
cooking_queries = pd.read_csv('datasets/queries/cooking_queries.csv').iloc[:10]
print("Cooking and DIY queries loaded.")
# # split train/test/validation - 80/10/10
# q_cooking_train, q_rem = train_test_split(cooking_queries, test_size=0.2, random_state=2022)
# q_cooking_test, q_cooking_validation = train_test_split(q_rem, test_size=0.5, random_state=2022)
# print(f"Cooking queries: training set size {len(q_cooking_train)}, test set size {len(q_cooking_test)}, validation set size {len(q_cooking_validation)}")
# Out:
# Cooking and DIY queries loaded.

# %% [markdown]
# ## Marqo Index Builder

# %%
from index_builder.marqo_index_builder import MarqoIndexBuilder

# %%
MarqoBuilder = MarqoIndexBuilder()
for taskmap_dir, dataset_name in zip(dataset_paths, dataset_names):
    MarqoBuilder.build_json_docs(input_dir=taskmap_dir,
                                    output_dir=output_temp_dir,
                                    dataset_name=dataset_name)
    
MarqoBuilder.build_index(input_dir=output_temp_dir,
                                    output_dir=output_index_dir)

# %% [markdown]
# ##### Query index example

# %%
results = MarqoBuilder.query_index("I want pasta")
import pprint
pprint.pprint(results)

# %% [markdown]
# ##### Filter usage example

# %%
results = MarqoBuilder.query_index_filter('I want pasta.', 'Domain:(wikihow)')
import pprint
pprint.pprint(results)

# %% [markdown]
# ### Relevance judgements

# %%
import pandas as pd
import jsonlines

# %%
queries = [
    "I want pizza pepperoni.",
    "I would like to make spaghetti bolognese.",
    "I want to prepare smoked salmon."
]

# %%
## Get rank and score from the marqo index and save these in a run file

run = []
for queryid, query in enumerate(queries):
    results = MarqoBuilder.query_index(query)
    for rank, doc in enumerate(results["hits"]):
        d = {}
        d["query_id"] = f'query-{queryid}'
        d["doc_id"] = doc["_id"]
        d["score"] = doc["_score"]
        d["rank"] = rank + 1
        run.append(d)

# jsonlines.Writer(open('qrels/run.jsonl', 'w')).write_all(run)

with open("qrels/run.run", "w") as f:
    lines = []
    for line in run:
        lines.append(f'{line["query_id"]} Q0 {line["doc_id"]} {line["rank"]} {line["score"]} t5-maxp\n')
    lines[-1] = lines[-1].replace("\n","")
    f.writelines(lines)

# %%
# qrel_reader = jsonlines.Reader(open("qrels/qrels.jsonl", "r"))
# qrels = pd.DataFrame([line for line in qrel_reader])
# qrels.head()

# %% [markdown]
# #### IR MEASURES
# - nDCG - normalized Discounted Cumulative Gain (nDCG) - highly relevant documents appearing lower in a search result list should be penalized as the graded relevance value is reduced logarithmically
# - precision - fraction of the documents retrieved that are relevant to the user's information need
# - recall - fraction of the documents that are relevant to the query that are successfully retrieved

# %%
import ir_measures
from ir_measures import *

qrels = ir_measures.read_trec_qrels('qrels/qrels.qrles')
run = ir_measures.read_trec_run('qrels/run.run')

ir_measures.calc_aggregate([nDCG@3, Precision@3, Recall@3], qrels, run)

# %% [markdown]
# ## Pyserini Index Builder

# %% [markdown]
# ### BM25

# %% [markdown]
# #### Recipees

# %%
from index_builder.pyserini_bm25_builder import PyseriniBM25Builder
output_temp_dir = os.path.join(os.getcwd(), "temp", "food", "system_index_sparse")
output_index_dir = os.path.join(os.getcwd(), "indexes", "food", "system_index_sparse")

# %%
PyseriniBM25Builder = PyseriniBM25Builder()
for taskmap_dir, dataset_name in zip(dataset_paths, dataset_names):
    PyseriniBM25Builder.build_json_docs(input_dir=taskmap_dir,
                                    output_dir=output_temp_dir,
                                    dataset_name=dataset_name)
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Generate index.
PyseriniBM25Builder.build_index(input_dir=output_temp_dir,
                                    output_dir=output_index_dir)
# Out:
# pyserini.index is deprecated, please use pyserini.index.lucene.
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2022-12-13 16:35:07,756 INFO  [main] index.IndexCollection (IndexCollection.java:643) - Setting log level to INFO
# 2022-12-13 16:35:07,759 INFO  [main] index.IndexCollection (IndexCollection.java:646) - Starting indexer...
# 2022-12-13 16:35:07,759 INFO  [main] index.IndexCollection (IndexCollection.java:647) - ============ Loading Parameters ============
# 2022-12-13 16:35:07,759 INFO  [main] index.IndexCollection (IndexCollection.java:648) - DocumentCollection path: /home/philip/task-search-quality/temp/food/system_index_sparse
# 2022-12-13 16:35:07,760 INFO  [main] index.IndexCollection (IndexCollection.java:649) - CollectionClass: JsonCollection
# 2022-12-13 16:35:07,760 INFO  [main] index.IndexCollection (IndexCollection.java:650) - Generator: DefaultLuceneDocumentGenerator
# 2022-12-13 16:35:07,761 INFO  [main] index.IndexCollection (IndexCollection.java:651) - Threads: 8
# 2022-12-13 16:35:07,761 INFO  [main] index.IndexCollection (IndexCollection.java:652) - Language: en
# 2022-12-13 16:35:07,762 INFO  [main] index.IndexCollection (IndexCollection.java:653) - Stemmer: porter
# 2022-12-13 16:35:07,762 INFO  [main] index.IndexCollection (IndexCollection.java:654) - Keep stopwords? false
# 2022-12-13 16:35:07,762 INFO  [main] index.IndexCollection (IndexCollection.java:655) - Stopwords: null
# 2022-12-13 16:35:07,763 INFO  [main] index.IndexCollection (IndexCollection.java:656) - Store positions? true
# 2022-12-13 16:35:07,763 INFO  [main] index.IndexCollection (IndexCollection.java:657) - Store docvectors? true
# 2022-12-13 16:35:07,763 INFO  [main] index.IndexCollection (IndexCollection.java:658) - Store document "contents" field? true
# 2022-12-13 16:35:07,764 INFO  [main] index.IndexCollection (IndexCollection.java:659) - Store document "raw" field? true
# 2022-12-13 16:35:07,764 INFO  [main] index.IndexCollection (IndexCollection.java:660) - Optimize (merge segments)? false
# 2022-12-13 16:35:07,765 INFO  [main] index.IndexCollection (IndexCollection.java:661) - Whitelist: null
# 2022-12-13 16:35:07,765 INFO  [main] index.IndexCollection (IndexCollection.java:662) - Pretokenized?: false
# 2022-12-13 16:35:07,765 INFO  [main] index.IndexCollection (IndexCollection.java:682) - Directly building Lucene indexes...
# 2022-12-13 16:35:07,766 INFO  [main] index.IndexCollection (IndexCollection.java:683) - Index path: /home/philip/task-search-quality/indexes/food/system_index_sparse
# 2022-12-13 16:35:07,768 INFO  [main] index.IndexCollection (IndexCollection.java:738) - ============ Indexing Collection ============
# 2022-12-13 16:35:07,988 INFO  [main] index.IndexCollection (IndexCollection.java:839) - Thread pool with 8 threads initialized.
# 2022-12-13 16:35:07,989 INFO  [main] index.IndexCollection (IndexCollection.java:841) - Initializing collection in /home/philip/task-search-quality/temp/food/system_index_sparse
# 2022-12-13 16:35:07,992 INFO  [main] index.IndexCollection (IndexCollection.java:850) - 2 files found
# 2022-12-13 16:35:07,992 INFO  [main] index.IndexCollection (IndexCollection.java:851) - Starting to index...
# 2022-12-13 16:35:21,452 DEBUG [pool-2-thread-1] index.IndexCollection$LocalIndexerThread (IndexCollection.java:248) - system_index_sparse/recipe1mln-recipe_taskmaps.jsonl: 51235 docs added.
# 2022-12-13 16:35:21,534 DEBUG [pool-2-thread-2] index.IndexCollection$LocalIndexerThread (IndexCollection.java:248) - system_index_sparse/recipe1mln-taskmaps.jsonl: 51235 docs added.
# 2022-12-13 16:35:24,383 INFO  [main] index.IndexCollection (IndexCollection.java:935) - Indexing Complete! 102,470 documents indexed
# 2022-12-13 16:35:24,383 INFO  [main] index.IndexCollection (IndexCollection.java:936) - ============ Final Counter Values ============
# 2022-12-13 16:35:24,383 INFO  [main] index.IndexCollection (IndexCollection.java:937) - indexed:          102,470
# 2022-12-13 16:35:24,384 INFO  [main] index.IndexCollection (IndexCollection.java:938) - unindexable:            0
# 2022-12-13 16:35:24,384 INFO  [main] index.IndexCollection (IndexCollection.java:939) - empty:                  0
# 2022-12-13 16:35:24,384 INFO  [main] index.IndexCollection (IndexCollection.java:940) - skipped:                0
# 2022-12-13 16:35:24,384 INFO  [main] index.IndexCollection (IndexCollection.java:941) - errors:                 0
# 2022-12-13 16:35:24,389 INFO  [main] index.IndexCollection (IndexCollection.java:944) - Total 102,470 documents indexed in 00:00:16

# %%
from pyserini.search.lucene import LuceneSearcher    
import json

searcher = LuceneSearcher(index_dir=output_index_dir)

last_utterance = "pasta"
top_k = 5

hits = searcher.search(q=last_utterance, k=top_k)

docs = []
docs_id = []
docs_score = []
for hit in hits:
    print(hit)
    doc_id, doc_score = hit.docid, hit.score
    doc = searcher.doc(docid=hit.docid)
    docs.append(doc.raw())
    print(doc_id, doc_score)

for doc_string in docs[0:1]:
    doc_json = json.loads(doc_string)
    taskmap_json = doc_json['recipe_document_json']
    # print(taskmap_json)
# Out:
# <io.anserini.search.SimpleSearcher$Result at 0x7f04f2138d10 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x1ff4a130 at 0x7f06311d9910>>
# cooking+recipe1m+a79f84d3a1c9e6f79fbb85a6caa69229 4.2845001220703125
# <io.anserini.search.SimpleSearcher$Result at 0x7f04fdd098b0 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x1ff4a148 at 0x7f04fdd4a690>>
# cooking+recipe1m+a79f84d3a1c9e6f79fbb85a6caa69229 4.284499168395996
# <io.anserini.search.SimpleSearcher$Result at 0x7f04fdd09810 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x1ff4a150 at 0x7f04fdd4aa70>>
# cooking+recipe1m+07e4c1ff548fdc39d1f5a0810d18624d 4.256899833679199
# <io.anserini.search.SimpleSearcher$Result at 0x7f04fdd09860 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x1ff4a158 at 0x7f04fdd4aab0>>
# cooking+recipe1m+07e4c1ff548fdc39d1f5a0810d18624d 4.256898880004883
# <io.anserini.search.SimpleSearcher$Result at 0x7f04fdd09900 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x1ff4a160 at 0x7f04fdd4abb0>>
# cooking+recipe1m+daa02e9a1f1031f769e827579ebcb800 4.166100025177002

# %% [markdown]
# ### Ance Encoding

# %%
from index_builder.pyserini_ance_builder import PyseriniAnceBuilder

output_temp_dir_ance = os.path.join(os.getcwd(), "temp", "food", "system_index_ance")
output_index_dir_ance = os.path.join(os.getcwd(), "indexes", "food", "system_index_ance")

# %%
PyseriniAnce = PyseriniAnceBuilder()
for taskmap_dir, dataset_name in zip(dataset_paths, dataset_names):
    PyseriniAnce.build_json_docs(input_dir=taskmap_dir,
                                    output_dir=output_temp_dir_ance,
                                    dataset_name=dataset_name)

# %%
# Generate index.
PyseriniAnce.build_index(input_dir=output_temp_dir_ance,
                            output_dir=output_index_dir_ance)

# %%
from pyserini.search.faiss import FaissSearcher, AnceQueryEncoder
encoder = AnceQueryEncoder("castorini/ance-msmarco-passage")
searcher = FaissSearcher(
    index_dir = output_index_dir_ance,
    query_encoder= encoder,
)

# %%
hits = searcher.search("pasta")

for i in range(0, 10):
    print(f'{i+1:2} {hits[i].docid} {hits[i].score}' )

# %% [markdown]
# ### BM25 + MonoT5

# %%
sys.path.insert(0, './pygaggle')
from pygaggle.rerank.base import Query, Text, hits_to_texts
from pygaggle.rerank.transformer import MonoT5

reranker =  MonoT5()
# Out:
# 2022-12-14 22:32:27 [INFO] loader: Loading faiss with AVX2 support.
# 2022-12-14 22:32:27 [INFO] loader: Successfully loaded faiss with AVX2 support.
# 2022-12-14 22:32:30.261209: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-12-14 22:32:33.468323: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-12-14 22:32:33.468453: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-12-14 22:32:33.468530: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (instance-alexa): /proc/driver/nvidia/version does not exist

# %%
from pyserini.search.lucene import LuceneSearcher
output_temp_dir = os.path.join(os.getcwd(), "temp", "system_index_sparse")
output_index_dir = os.path.join(os.getcwd(), "indexes", "food", "system_index_sparse")

query = Query('pasta')
searcher = LuceneSearcher(index_dir=output_index_dir)
hits = searcher.search(query.text)
texts = hits_to_texts(hits)

# %%
for i in range(0, 10):
    print(f'{i+1:2} {texts[i].metadata["docid"]:15} {texts[i].score:.5f} {texts[i].text}')
# Out:
#  1 cooking+recipe1m+e913e7d20377b736080a0e7df5f7a37a 2.86270 {
#   "id" : "cooking+recipe1m+e913e7d20377b736080a0e7df5f7a37a",
#   "contents" : "Girls Night Pasta. 16 ounces, weight Rotini Pasta, Cooked 1 whole Roasted Chicken, Picked 1 cup Sun-Dried Tomatoes, Diced 1/2 cups Grated Parmesan Cheese 2 ounces, weight Pine Nuts, Toasted 1 cup Pesto Sauce (or To Taste) 1 cup Reserved Pasta Water (add To Taste) 2 dashes Salt And Pepper, to taste Start off by boiling some salted pasta water, and cook the pasta until almost al dente. Reserve 1 cup of pasta water, then drain the pasta and set it aside (the pasta will finish cooking when you stir in the other ingredients). Pick the chicken, dice the sundried tomatoes, and grate the Parmesan. Lightly toast the pine nuts in a skillet, watching carefully so that they dont burn. Over low heat, stir the pesto, tomatoes, chicken, and pine nuts into the pasta until incorporated and the pasta is al dente. If the pasta looks dry, add in a splash of pasta water. Keep adding pasta water until the consistency is to your taste. Season with salt and pepper. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+e913e7d20377b736080a0e7df5f7a37a",
#     "title" : "Girls Night Pasta",
#     "sourceUrl" : "http://tastykitchen.com/recipes/main-courses/girlse28099-night-pasta/",
#     "requirementList" : [ {
#       "uniqueId" : "50dba85d-ca27-4625-94e4-5d26844ec66f",
#       "type" : "HARDWARE",
#       "name" : "16 ounces, weight Rotini Pasta, Cooked"
#     }, {
#       "uniqueId" : "d5641538-5764-4446-9562-f7f4feaf28a7",
#       "type" : "HARDWARE",
#       "name" : "1 whole Roasted Chicken, Picked"
#     }, {
#       "uniqueId" : "4fb0e6ee-4923-4a3f-9e6a-9f01dc40323a",
#       "type" : "HARDWARE",
#       "name" : "1 cup Sun-Dried Tomatoes, Diced"
#     }, {
#       "uniqueId" : "225b9d8a-4900-4a18-895f-082b1692ea65",
#       "type" : "HARDWARE",
#       "name" : "1/2 cups Grated Parmesan Cheese"
#     }, {
#       "uniqueId" : "73f90831-ebcc-416f-98db-c36987181b4f",
#       "type" : "HARDWARE",
#       "name" : "2 ounces, weight Pine Nuts, Toasted"
#     }, {
#       "uniqueId" : "d2d059c9-08ed-4aed-9246-ca03decf2007",
#       "type" : "HARDWARE",
#       "name" : "1 cup Pesto Sauce (or To Taste)"
#     }, {
#       "uniqueId" : "d2f57306-cd4f-4b86-9b24-9db7c4bf18cc",
#       "type" : "HARDWARE",
#       "name" : "1 cup Reserved Pasta Water (add To Taste)"
#     }, {
#       "uniqueId" : "a4642e9f-fd72-43d5-ad3c-853aef39446b",
#       "type" : "HARDWARE",
#       "name" : "2 dashes Salt And Pepper, to taste"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "56655348-d182-4070-b102-56dd8c934479",
#       "response" : {
#         "speechText" : "Start off by boiling some salted pasta water, and cook the pasta until almost al dente.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Start off by boiling some salted pasta water, and cook the pasta until almost al dente." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "0a4d80fa-6c2e-43ad-9707-d820aa9a6645",
#       "response" : {
#         "speechText" : "Reserve 1 cup of pasta water, then drain the pasta and set it aside (the pasta will finish cooking when you stir in the other ingredients).",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Reserve 1 cup of pasta water, then drain the pasta and set it aside (the pasta will finish cooking when you stir in the other ingredients)." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "3f6f1de0-1212-4225-b7b3-619ccd5a75ca",
#       "response" : {
#         "speechText" : "Pick the chicken, dice the sundried tomatoes, and grate the Parmesan.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Pick the chicken, dice the sundried tomatoes, and grate the Parmesan." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "d9f58b16-574e-4b5d-8e87-8e611423aebc",
#       "response" : {
#         "speechText" : "Lightly toast the pine nuts in a skillet, watching carefully so that they dont burn.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Lightly toast the pine nuts in a skillet, watching carefully so that they dont burn." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "43769eb4-db3b-42fd-b7a0-27b39d8eda4e",
#       "response" : {
#         "speechText" : "Over low heat, stir the pesto, tomatoes, chicken, and pine nuts into the pasta until incorporated and the pasta is al dente.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Over low heat, stir the pesto, tomatoes, chicken, and pine nuts into the pasta until incorporated and the pasta is al dente." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "270e45eb-cc88-43bd-b986-a0675fdf11e9",
#       "response" : {
#         "speechText" : "If the pasta looks dry, add in a splash of pasta water.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "If the pasta looks dry, add in a splash of pasta water." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "e33c5d4c-2232-4f3f-88ca-1ec865394bf5",
#       "response" : {
#         "speechText" : "Keep adding pasta water until the consistency is to your taste.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Keep adding pasta water until the consistency is to your taste." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "82ca863b-382f-42e0-95a1-977c43a88198",
#       "response" : {
#         "speechText" : "Season with salt and pepper.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Season with salt and pepper." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "d9f58b16-574e-4b5d-8e87-8e611423aebc",
#       "idTo" : "43769eb4-db3b-42fd-b7a0-27b39d8eda4e"
#     }, {
#       "idFrom" : "43769eb4-db3b-42fd-b7a0-27b39d8eda4e",
#       "idTo" : "270e45eb-cc88-43bd-b986-a0675fdf11e9"
#     }, {
#       "idFrom" : "270e45eb-cc88-43bd-b986-a0675fdf11e9",
#       "idTo" : "e33c5d4c-2232-4f3f-88ca-1ec865394bf5"
#     }, {
#       "idFrom" : "0a4d80fa-6c2e-43ad-9707-d820aa9a6645",
#       "idTo" : "3f6f1de0-1212-4225-b7b3-619ccd5a75ca"
#     }, {
#       "idFrom" : "e33c5d4c-2232-4f3f-88ca-1ec865394bf5",
#       "idTo" : "82ca863b-382f-42e0-95a1-977c43a88198"
#     }, {
#       "idFrom" : "3f6f1de0-1212-4225-b7b3-619ccd5a75ca",
#       "idTo" : "d9f58b16-574e-4b5d-8e87-8e611423aebc"
#     }, {
#       "idFrom" : "56655348-d182-4070-b102-56dd8c934479",
#       "idTo" : "0a4d80fa-6c2e-43ad-9707-d820aa9a6645"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "tastykitchen.com"
#   }
# }
#  2 cooking+recipe1m+679e29e45c779244d693d52b67938144 2.85230 {
#   "id" : "cooking+recipe1m+679e29e45c779244d693d52b67938144",
#   "contents" : "Bavette Cacio e Pepe. Kosher salt 12 ounces bavette or linguine fine 1/2 cup extra-virgin olive oil 1 tablespoon plus 1 teaspoon fresh coarsley ground black pepper, plus more to taste 1/4 cup freshly grated Parmigiano-Reggiano 1/4 cup freshly grated pecorino romano 4 teaspoons finishing-quality extra-virgin olive oil Fill a pasta pot or a large stockpot with 6 quarts of water, add 6 tablespoons of salt, and bring the water to a boil over high heat. If you are not using a pasta pot, put a colander in the sink or have a wire strainer handy to lift the pasta out of the pot. Drop the bavette into the boiling water, stir to prevent the strands from sticking together, partially cover the pot so the water returns to a boil quickly and continues boiling, and cook the pasta, using the time indicated on the package as a guide, until its al dente. While the pasta is cooking, combine the olive oil, pepper, and 1/2 cup of the pasta cooking water in a large saute pan. About 1 minute before the pasta is done, place the sauce over high heat. Lift the pasta out of the cooking water, or reserve 1 cup of the water and drain the pasta, and immediately add the pasta to the pan with the sauce. Cook the pasta with the sauce for 2 minutes, stirring with a rubber spatula or tongs, to stain the pasta with the sauce, adding some of the reserved pasta water if the pasta is dry and sticky instead of slippery and glistening. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+679e29e45c779244d693d52b67938144",
#     "title" : "Bavette Cacio e Pepe",
#     "sourceUrl" : "http://www.epicurious.com/recipes/food/views/bavette-cacio-e-pepe-393592",
#     "requirementList" : [ {
#       "uniqueId" : "3125af90-baac-4e0b-a2e7-68bf3990ccd2",
#       "type" : "HARDWARE",
#       "name" : "Kosher salt"
#     }, {
#       "uniqueId" : "869d7b76-9399-4919-8aa5-44b16dc328c0",
#       "type" : "HARDWARE",
#       "name" : "12 ounces bavette or linguine fine"
#     }, {
#       "uniqueId" : "bdc64eed-c97f-44cc-a296-dccd2ea30f59",
#       "type" : "HARDWARE",
#       "name" : "1/2 cup extra-virgin olive oil"
#     }, {
#       "uniqueId" : "599b16a0-abda-41a5-af74-198399b1bafc",
#       "type" : "HARDWARE",
#       "name" : "1 tablespoon plus 1 teaspoon fresh coarsley ground black pepper, plus more to taste"
#     }, {
#       "uniqueId" : "63986f1c-8ac8-4afb-b819-315a29f5b49d",
#       "type" : "HARDWARE",
#       "name" : "1/4 cup freshly grated Parmigiano-Reggiano"
#     }, {
#       "uniqueId" : "b9fb542a-3e64-4cef-96fa-e5a07818a7e4",
#       "type" : "HARDWARE",
#       "name" : "1/4 cup freshly grated pecorino romano"
#     }, {
#       "uniqueId" : "f0770d9b-1287-4cba-a2e8-769924a67a5b",
#       "type" : "HARDWARE",
#       "name" : "4 teaspoons finishing-quality extra-virgin olive oil"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "5fec8098-6685-4437-826d-7f18305ba227",
#       "response" : {
#         "speechText" : "Fill a pasta pot or a large stockpot with 6 quarts of water, add 6 tablespoons of salt, and bring the water to a boil over high heat.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Fill a pasta pot or a large stockpot with 6 quarts of water, add 6 tablespoons of salt, and bring the water to a boil over high heat." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "1b5f767f-335b-4576-b791-63519ab1a1f8",
#       "response" : {
#         "speechText" : "If you are not using a pasta pot, put a colander in the sink or have a wire strainer handy to lift the pasta out of the pot.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "If you are not using a pasta pot, put a colander in the sink or have a wire strainer handy to lift the pasta out of the pot." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "0da640e3-3b5b-4498-a1c2-59aeea4baacb",
#       "response" : {
#         "speechText" : "Drop the bavette into the boiling water, stir to prevent the strands from sticking together, partially cover the pot so the water returns to a boil quickly and continues boiling, and cook the pasta, using the time indicated on the package as a guide, until its al dente.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Drop the bavette into the boiling water, stir to prevent the strands from sticking together, partially cover the pot so the water returns to a boil quickly and continues boiling, and cook the pasta, using the time indicated on the package as a guide, until its al dente." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "4cbca036-1b84-4f57-9767-f1aec5f1d71f",
#       "response" : {
#         "speechText" : "While the pasta is cooking, combine the olive oil, pepper, and 1/2 cup of the pasta cooking water in a large saute pan.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "While the pasta is cooking, combine the olive oil, pepper, and 1/2 cup of the pasta cooking water in a large saute pan." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "8d5997e9-d110-48f6-b2f4-672b884323a8",
#       "response" : {
#         "speechText" : "About 1 minute before the pasta is done, place the sauce over high heat.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "About 1 minute before the pasta is done, place the sauce over high heat." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "383e0f46-8d1b-422f-bfcb-37fbe6c91fe7",
#       "response" : {
#         "speechText" : "Lift the pasta out of the cooking water, or reserve 1 cup of the water and drain the pasta, and immediately add the pasta to the pan with the sauce.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Lift the pasta out of the cooking water, or reserve 1 cup of the water and drain the pasta, and immediately add the pasta to the pan with the sauce." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "fa285e51-4d42-460f-b288-37c2a67f5b05",
#       "response" : {
#         "speechText" : "Cook the pasta with the sauce for 2 minutes, stirring with a rubber spatula or tongs, to stain the pasta with the sauce, adding some of the reserved pasta water if the pasta is dry and sticky instead of slippery and glistening.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook the pasta with the sauce for 2 minutes, stirring with a rubber spatula or tongs, to stain the pasta with the sauce, adding some of the reserved pasta water if the pasta is dry and sticky instead of slippery and glistening." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "0da640e3-3b5b-4498-a1c2-59aeea4baacb",
#       "idTo" : "4cbca036-1b84-4f57-9767-f1aec5f1d71f"
#     }, {
#       "idFrom" : "383e0f46-8d1b-422f-bfcb-37fbe6c91fe7",
#       "idTo" : "fa285e51-4d42-460f-b288-37c2a67f5b05"
#     }, {
#       "idFrom" : "8d5997e9-d110-48f6-b2f4-672b884323a8",
#       "idTo" : "383e0f46-8d1b-422f-bfcb-37fbe6c91fe7"
#     }, {
#       "idFrom" : "5fec8098-6685-4437-826d-7f18305ba227",
#       "idTo" : "1b5f767f-335b-4576-b791-63519ab1a1f8"
#     }, {
#       "idFrom" : "1b5f767f-335b-4576-b791-63519ab1a1f8",
#       "idTo" : "0da640e3-3b5b-4498-a1c2-59aeea4baacb"
#     }, {
#       "idFrom" : "4cbca036-1b84-4f57-9767-f1aec5f1d71f",
#       "idTo" : "8d5997e9-d110-48f6-b2f4-672b884323a8"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "epicurious"
#   }
# }
#  3 cooking+recipe1m+81d98be9084ffad15fd31bbca9a62fd4 2.84700 {
#   "id" : "cooking+recipe1m+81d98be9084ffad15fd31bbca9a62fd4",
#   "contents" : "Pasta Carbonara With Sweet Peas. 8 ounces penne pasta (or other tubular pasta) 12 cup thick slab bacon, diced 12 cup onion, chopped 1 garlic clove, sliced 14 cup heavy cream 14 teaspoon crushed red pepper flakes 14 teaspoon ground nutmeg 2 egg yolks 1 cup green peas (fresh or frozen) 12 teaspoon fresh ground black pepper 12 cup parmesan cheese, grated Boil pasta in salted water. Meanwhile render diced bacon. Shortly before it's completely rendered, add chopped onion and garlic slices. Cook until the onion is soft and add cream, pepper flakes, and nutmeg. When the pasta is cooked, transfer the pasta with a slotted spoon or large sieve directly from the pasta pot to the pan with the bacon. Do not drain the pasta first; you want some of the pasta water in the dish. Add the peas to the hot pasta water to blanch. Turn off the fire under the pasta and bacon mixture and add the eggs, stirring to thoroughly coat each pasta tube with the egg. Take care not to allow the egg yolks to scramble at the bottom of the pan. Transfer the peas with the slotted spoon or sieve from the pasta water to the pan along with the black pepper and parmesan. Continue to stir. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+81d98be9084ffad15fd31bbca9a62fd4",
#     "title" : "Pasta Carbonara With Sweet Peas",
#     "sourceUrl" : "http://www.food.com/recipe/pasta-carbonara-with-sweet-peas-503999",
#     "requirementList" : [ {
#       "uniqueId" : "099d5472-2c45-4123-ba04-b21c074ef4bb",
#       "type" : "HARDWARE",
#       "name" : "8 ounces penne pasta (or other tubular pasta)"
#     }, {
#       "uniqueId" : "54e8a5cc-cd99-4653-bbaa-18651de37397",
#       "type" : "HARDWARE",
#       "name" : "12 cup thick slab bacon, diced"
#     }, {
#       "uniqueId" : "b84744ec-17f0-4022-bbdc-b296f74f27a2",
#       "type" : "HARDWARE",
#       "name" : "12 cup onion, chopped"
#     }, {
#       "uniqueId" : "008ef86b-0491-4f28-88b2-fbc578431463",
#       "type" : "HARDWARE",
#       "name" : "1 garlic clove, sliced"
#     }, {
#       "uniqueId" : "6ea86bc3-2a61-4917-9ed9-622a13027878",
#       "type" : "HARDWARE",
#       "name" : "14 cup heavy cream"
#     }, {
#       "uniqueId" : "84f4377e-6b9a-4c11-809d-87eddb5640a6",
#       "type" : "HARDWARE",
#       "name" : "14 teaspoon crushed red pepper flakes"
#     }, {
#       "uniqueId" : "57f5ee49-ac9b-47b2-9fea-cb12a65577f3",
#       "type" : "HARDWARE",
#       "name" : "14 teaspoon ground nutmeg"
#     }, {
#       "uniqueId" : "7f7e4beb-71f5-463c-8da9-6d2ac38f021a",
#       "type" : "HARDWARE",
#       "name" : "2 egg yolks"
#     }, {
#       "uniqueId" : "c87a6e37-0314-420b-b7d5-7e285a976fc3",
#       "type" : "HARDWARE",
#       "name" : "1 cup green peas (fresh or frozen)"
#     }, {
#       "uniqueId" : "85eef49d-0a23-4cf0-87f8-fc15de40c029",
#       "type" : "HARDWARE",
#       "name" : "12 teaspoon fresh ground black pepper"
#     }, {
#       "uniqueId" : "7283cb98-cf29-42bd-896e-70286ab3a10d",
#       "type" : "HARDWARE",
#       "name" : "12 cup parmesan cheese, grated"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "30ec053e-74ff-48b8-9077-39c038387f9d",
#       "response" : {
#         "speechText" : "Boil pasta in salted water.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Boil pasta in salted water." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "1baa96e0-d677-4030-863e-95f5562cf823",
#       "response" : {
#         "speechText" : "Meanwhile render diced bacon.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Meanwhile render diced bacon." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "ba81132a-97a1-4a01-b1c2-c8cf28b635c3",
#       "response" : {
#         "speechText" : "Shortly before it's completely rendered, add chopped onion and garlic slices.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Shortly before it's completely rendered, add chopped onion and garlic slices." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "44ce30e7-9ecf-49e7-b035-1e473b498044",
#       "response" : {
#         "speechText" : "Cook until the onion is soft and add cream, pepper flakes, and nutmeg.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook until the onion is soft and add cream, pepper flakes, and nutmeg." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "ce94a98a-bc9b-4e12-8e15-08244326c1cf",
#       "response" : {
#         "speechText" : "When the pasta is cooked, transfer the pasta with a slotted spoon or large sieve directly from the pasta pot to the pan with the bacon.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "When the pasta is cooked, transfer the pasta with a slotted spoon or large sieve directly from the pasta pot to the pan with the bacon." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "82f91765-1548-4964-8a8d-1e99aa67edce",
#       "response" : {
#         "speechText" : "Do not drain the pasta first; you want some of the pasta water in the dish.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Do not drain the pasta first; you want some of the pasta water in the dish." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "00df6c22-d250-4439-8ad9-f8b087633974",
#       "response" : {
#         "speechText" : "Add the peas to the hot pasta water to blanch.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the peas to the hot pasta water to blanch." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "38dd2f83-4f3e-4a71-be1e-8956366d0ad5",
#       "response" : {
#         "speechText" : "Turn off the fire under the pasta and bacon mixture and add the eggs, stirring to thoroughly coat each pasta tube with the egg.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Turn off the fire under the pasta and bacon mixture and add the eggs, stirring to thoroughly coat each pasta tube with the egg." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "aabf2233-aadd-4935-9cea-38575d16efb5",
#       "response" : {
#         "speechText" : "Take care not to allow the egg yolks to scramble at the bottom of the pan.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Take care not to allow the egg yolks to scramble at the bottom of the pan." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "2529720e-348b-4295-8a8e-f1f96e9f5a20",
#       "response" : {
#         "speechText" : "Transfer the peas with the slotted spoon or sieve from the pasta water to the pan along with the black pepper and parmesan.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Transfer the peas with the slotted spoon or sieve from the pasta water to the pan along with the black pepper and parmesan." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "c0b80951-17f8-44a0-83b6-a06bba6c34d7",
#       "response" : {
#         "speechText" : "Continue to stir.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Continue to stir." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "00df6c22-d250-4439-8ad9-f8b087633974",
#       "idTo" : "38dd2f83-4f3e-4a71-be1e-8956366d0ad5"
#     }, {
#       "idFrom" : "82f91765-1548-4964-8a8d-1e99aa67edce",
#       "idTo" : "00df6c22-d250-4439-8ad9-f8b087633974"
#     }, {
#       "idFrom" : "ba81132a-97a1-4a01-b1c2-c8cf28b635c3",
#       "idTo" : "44ce30e7-9ecf-49e7-b035-1e473b498044"
#     }, {
#       "idFrom" : "2529720e-348b-4295-8a8e-f1f96e9f5a20",
#       "idTo" : "c0b80951-17f8-44a0-83b6-a06bba6c34d7"
#     }, {
#       "idFrom" : "44ce30e7-9ecf-49e7-b035-1e473b498044",
#       "idTo" : "ce94a98a-bc9b-4e12-8e15-08244326c1cf"
#     }, {
#       "idFrom" : "ce94a98a-bc9b-4e12-8e15-08244326c1cf",
#       "idTo" : "82f91765-1548-4964-8a8d-1e99aa67edce"
#     }, {
#       "idFrom" : "38dd2f83-4f3e-4a71-be1e-8956366d0ad5",
#       "idTo" : "aabf2233-aadd-4935-9cea-38575d16efb5"
#     }, {
#       "idFrom" : "aabf2233-aadd-4935-9cea-38575d16efb5",
#       "idTo" : "2529720e-348b-4295-8a8e-f1f96e9f5a20"
#     }, {
#       "idFrom" : "1baa96e0-d677-4030-863e-95f5562cf823",
#       "idTo" : "ba81132a-97a1-4a01-b1c2-c8cf28b635c3"
#     }, {
#       "idFrom" : "30ec053e-74ff-48b8-9077-39c038387f9d",
#       "idTo" : "1baa96e0-d677-4030-863e-95f5562cf823"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
#  4 cooking+recipe1m+ede56331fbee463f4d4e08dd63d363bd 2.84520 {
#   "id" : "cooking+recipe1m+ede56331fbee463f4d4e08dd63d363bd",
#   "contents" : "Pasta With Ham and Herbed Cheese. 1 lb whole-wheat spiral shaped pasta 2 (5 ounce) packagessoft herbed cheese (such as Alouette or Boursin ) 14 lb boiled ham, cut into cubes salt and pepper 2 tablespoons fresh parsley, chopped Bring a large pot of salted water to a boil and prepare pasta according to package directions. Set aside 1 cup pasta cooking water and drain pasta. Return pasta to pot; crumble pieces of cheese over pasta. Add ham, salt and pepper to taste and parsley to pasta mixture. Pour in 1/2 cup pasta cooking water and toss or stir until cheese is melted and pasta is coated. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+ede56331fbee463f4d4e08dd63d363bd",
#     "title" : "Pasta With Ham and Herbed Cheese",
#     "sourceUrl" : "http://www.food.com/recipe/pasta-with-ham-and-herbed-cheese-491988",
#     "requirementList" : [ {
#       "uniqueId" : "6893b427-69ca-4e85-b85e-468c4dfe215c",
#       "type" : "HARDWARE",
#       "name" : "1 lb whole-wheat spiral shaped pasta"
#     }, {
#       "uniqueId" : "9c9fbf18-ab1d-43cc-bf43-9da16126d022",
#       "type" : "HARDWARE",
#       "name" : "2 (5 ounce) packagessoft herbed cheese (such as Alouette or Boursin )"
#     }, {
#       "uniqueId" : "9372356d-dab7-4eac-a44c-b6db0427374c",
#       "type" : "HARDWARE",
#       "name" : "14 lb boiled ham, cut into cubes"
#     }, {
#       "uniqueId" : "e4ebb1a9-1b3b-4ee6-a05c-747c511f66c3",
#       "type" : "HARDWARE",
#       "name" : "salt and pepper"
#     }, {
#       "uniqueId" : "1e2741b2-4ebb-4eaf-953e-8a76059eb233",
#       "type" : "HARDWARE",
#       "name" : "2 tablespoons fresh parsley, chopped"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "d3319cb8-054b-4af9-b25e-d3fbc457a183",
#       "response" : {
#         "speechText" : "Bring a large pot of salted water to a boil and prepare pasta according to package directions.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Bring a large pot of salted water to a boil and prepare pasta according to package directions." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "2e1632f1-6b43-4b40-a0d5-bba8dab0b20a",
#       "response" : {
#         "speechText" : "Set aside 1 cup pasta cooking water and drain pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Set aside 1 cup pasta cooking water and drain pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "344d6ee9-6116-4306-800a-e881197dd1be",
#       "response" : {
#         "speechText" : "Return pasta to pot; crumble pieces of cheese over pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Return pasta to pot; crumble pieces of cheese over pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "6a52833e-c445-48ae-9d8d-075fb7b54cad",
#       "response" : {
#         "speechText" : "Add ham, salt and pepper to taste and parsley to pasta mixture.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add ham, salt and pepper to taste and parsley to pasta mixture." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "2c24340c-a63e-47db-9adc-eae1b521a586",
#       "response" : {
#         "speechText" : "Pour in 1/2 cup pasta cooking water and toss or stir until cheese is melted and pasta is coated.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Pour in 1/2 cup pasta cooking water and toss or stir until cheese is melted and pasta is coated." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "344d6ee9-6116-4306-800a-e881197dd1be",
#       "idTo" : "6a52833e-c445-48ae-9d8d-075fb7b54cad"
#     }, {
#       "idFrom" : "6a52833e-c445-48ae-9d8d-075fb7b54cad",
#       "idTo" : "2c24340c-a63e-47db-9adc-eae1b521a586"
#     }, {
#       "idFrom" : "d3319cb8-054b-4af9-b25e-d3fbc457a183",
#       "idTo" : "2e1632f1-6b43-4b40-a0d5-bba8dab0b20a"
#     }, {
#       "idFrom" : "2e1632f1-6b43-4b40-a0d5-bba8dab0b20a",
#       "idTo" : "344d6ee9-6116-4306-800a-e881197dd1be"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
#  5 cooking+recipe1m+18f9d712dc70ea0479257dc5a09a643d 2.82980 {
#   "id" : "cooking+recipe1m+18f9d712dc70ea0479257dc5a09a643d",
#   "contents" : "Meat and Cheese Pasta Salad. 1 (12 ounce) box tri-color spiral pasta 1 tomatoes 1 green bell pepper 1 (5 ounce) containerof treasure cave feta cheese with garlic and herbs 6 ounces sliced green olives 23 cup mild pepper rings 3 ounces sliced pepperoni 8 ounces genoa salami 4 ounces mozzarella cheese 2 tablespoons mccormick Salad Supreme dry seasoning 4 tablespoons classico sun-dried tomato pesto 23 cup wishbone robusto Italian dressing Cook rainbow rotini according to the directions on the box. When pasta is done run pasta under cold water to cool. Drain water off pasta. Dice tomato and add it to the pasta. Dice the green bell pepper and add it to the pasta. Add the feta cheese, green olives, mild pepper rings, and sliced pepperoni to the pasta. Chop Genoa Salami into bite size pieces and add to the pasta (you will want to have the deli to slice the salami on the thick side). Cut mozzarella cheese into small squares and add to the pasta. Add the McCormick Salad Supreme, sun-dried tomato pesto, and Italian dressing to the pasta salad. Mix well after adding each ingredient. Refrigerate for at least one or more hours to let all the flavors mix in to the pasta. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+18f9d712dc70ea0479257dc5a09a643d",
#     "title" : "Meat and Cheese Pasta Salad",
#     "sourceUrl" : "http://www.food.com/recipe/meat-and-cheese-pasta-salad-231469",
#     "requirementList" : [ {
#       "uniqueId" : "67550abf-0f3d-4995-b0bf-01e9e4eac42e",
#       "type" : "HARDWARE",
#       "name" : "1 (12 ounce) box tri-color spiral pasta"
#     }, {
#       "uniqueId" : "c8ed44ea-bd18-41e7-8e4b-985eefaf5830",
#       "type" : "HARDWARE",
#       "name" : "1 tomatoes"
#     }, {
#       "uniqueId" : "3fd7ce67-d1fd-432e-af96-1b7f3a6deec5",
#       "type" : "HARDWARE",
#       "name" : "1 green bell pepper"
#     }, {
#       "uniqueId" : "e0c121c0-e165-48f2-8cf0-1f14d16c2106",
#       "type" : "HARDWARE",
#       "name" : "1 (5 ounce) containerof treasure cave feta cheese with garlic and herbs"
#     }, {
#       "uniqueId" : "3af135cc-1a50-4219-a241-b121da1425af",
#       "type" : "HARDWARE",
#       "name" : "6 ounces sliced green olives"
#     }, {
#       "uniqueId" : "13d4b143-14eb-463a-8a3b-2e8b95767f7f",
#       "type" : "HARDWARE",
#       "name" : "23 cup mild pepper rings"
#     }, {
#       "uniqueId" : "abe843a7-ab6e-4444-b94d-d5df59c9c5eb",
#       "type" : "HARDWARE",
#       "name" : "3 ounces sliced pepperoni"
#     }, {
#       "uniqueId" : "b79a69db-f952-4247-859b-062f001d60f5",
#       "type" : "HARDWARE",
#       "name" : "8 ounces genoa salami"
#     }, {
#       "uniqueId" : "57def927-3a81-4bed-b103-b821c46c4441",
#       "type" : "HARDWARE",
#       "name" : "4 ounces mozzarella cheese"
#     }, {
#       "uniqueId" : "60015027-61e3-4441-813d-f7540e59167c",
#       "type" : "HARDWARE",
#       "name" : "2 tablespoons mccormick Salad Supreme dry seasoning"
#     }, {
#       "uniqueId" : "f07559fa-e6f1-42cf-aca6-0e9cef926a23",
#       "type" : "HARDWARE",
#       "name" : "4 tablespoons classico sun-dried tomato pesto"
#     }, {
#       "uniqueId" : "f81f990b-7e88-47ba-8dec-12a83979ab31",
#       "type" : "HARDWARE",
#       "name" : "23 cup wishbone robusto Italian dressing"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "9928123f-dea4-4f4d-9b05-7e4436ba058d",
#       "response" : {
#         "speechText" : "Cook rainbow rotini according to the directions on the box.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook rainbow rotini according to the directions on the box." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "9f8165ca-d083-48f2-999f-978d6f5019d5",
#       "response" : {
#         "speechText" : "When pasta is done run pasta under cold water to cool.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "When pasta is done run pasta under cold water to cool." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "6b1d66b3-577e-4667-9c08-4477fd3f321b",
#       "response" : {
#         "speechText" : "Drain water off pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Drain water off pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "9bb3bf34-c884-43e5-9fc2-e569028baf66",
#       "response" : {
#         "speechText" : "Dice tomato and add it to the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Dice tomato and add it to the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "4be9530a-c4d5-47dd-ac60-7d77913331c6",
#       "response" : {
#         "speechText" : "Dice the green bell pepper and add it to the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Dice the green bell pepper and add it to the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "62abfdc5-70c1-47b8-9946-b5f3cde1bc9c",
#       "response" : {
#         "speechText" : "Add the feta cheese, green olives, mild pepper rings, and sliced pepperoni to the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the feta cheese, green olives, mild pepper rings, and sliced pepperoni to the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "bd824919-f844-40da-8c01-8ca766fde5ac",
#       "response" : {
#         "speechText" : "Chop Genoa Salami into bite size pieces and add to the pasta (you will want to have the deli to slice the salami on the thick side).",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Chop Genoa Salami into bite size pieces and add to the pasta (you will want to have the deli to slice the salami on the thick side)." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "e1a1eb64-7a54-4ac7-9cde-89420116e0be",
#       "response" : {
#         "speechText" : "Cut mozzarella cheese into small squares and add to the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cut mozzarella cheese into small squares and add to the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "0bf4463b-6b79-41a9-8e93-7e40f15b914d",
#       "response" : {
#         "speechText" : "Add the McCormick Salad Supreme, sun-dried tomato pesto, and Italian dressing to the pasta salad.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the McCormick Salad Supreme, sun-dried tomato pesto, and Italian dressing to the pasta salad." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "9b6a6735-068a-4c6b-ad80-0d741485e688",
#       "response" : {
#         "speechText" : "Mix well after adding each ingredient.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Mix well after adding each ingredient." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "012ae70f-f5f1-4b81-9090-16f02cef75c9",
#       "response" : {
#         "speechText" : "Refrigerate for at least one or more hours to let all the flavors mix in to the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Refrigerate for at least one or more hours to let all the flavors mix in to the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "e1a1eb64-7a54-4ac7-9cde-89420116e0be",
#       "idTo" : "0bf4463b-6b79-41a9-8e93-7e40f15b914d"
#     }, {
#       "idFrom" : "0bf4463b-6b79-41a9-8e93-7e40f15b914d",
#       "idTo" : "9b6a6735-068a-4c6b-ad80-0d741485e688"
#     }, {
#       "idFrom" : "6b1d66b3-577e-4667-9c08-4477fd3f321b",
#       "idTo" : "9bb3bf34-c884-43e5-9fc2-e569028baf66"
#     }, {
#       "idFrom" : "9928123f-dea4-4f4d-9b05-7e4436ba058d",
#       "idTo" : "9f8165ca-d083-48f2-999f-978d6f5019d5"
#     }, {
#       "idFrom" : "bd824919-f844-40da-8c01-8ca766fde5ac",
#       "idTo" : "e1a1eb64-7a54-4ac7-9cde-89420116e0be"
#     }, {
#       "idFrom" : "9bb3bf34-c884-43e5-9fc2-e569028baf66",
#       "idTo" : "4be9530a-c4d5-47dd-ac60-7d77913331c6"
#     }, {
#       "idFrom" : "62abfdc5-70c1-47b8-9946-b5f3cde1bc9c",
#       "idTo" : "bd824919-f844-40da-8c01-8ca766fde5ac"
#     }, {
#       "idFrom" : "4be9530a-c4d5-47dd-ac60-7d77913331c6",
#       "idTo" : "62abfdc5-70c1-47b8-9946-b5f3cde1bc9c"
#     }, {
#       "idFrom" : "9b6a6735-068a-4c6b-ad80-0d741485e688",
#       "idTo" : "012ae70f-f5f1-4b81-9090-16f02cef75c9"
#     }, {
#       "idFrom" : "9f8165ca-d083-48f2-999f-978d6f5019d5",
#       "idTo" : "6b1d66b3-577e-4667-9c08-4477fd3f321b"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
#  6 cooking+recipe1m+3af7e0c33b783b780390247a1c4cedda 2.82980 {
#   "id" : "cooking+recipe1m+3af7e0c33b783b780390247a1c4cedda",
#   "contents" : "Bowtie Pasta and Peas With Bacon. 4 slices bacon, cooked and chopped 1 lb bow tie pasta 2 pinches salt for the pasta water 1 tablespoon oil 1 onion, chopped 4 garlic cloves, minced 1 cup of pasta water 1 tablespoon parsley, chopped salt and pepper, to taste cajun seasoning or creole seasoning, to taste 23 cup half-and-half 1 (15 ounce) can lasueur early peas, drained 12 cup parmesan cheese, grated Cook the bacon and chop; set aside. In a large pot add two big pinches of salt to boiling water for pasta. Cook pasta according to package directions. Reserve 1 cup of the pasta water before draining the pasta. When pasta is just about ready, in the pan you cooked bacon in add oil and heat over medium heat, saute the onion until soft, but not browned, about 4 minutes. Add the garlic and cook another minute. Stir in one cup of the pasta water and the parsley, salt, pepper, Cajun seasoning and half and half; bring to a boil. Add the peas, reduce heat and simmer just until the peas are warmed through. Taste and adjust seasonings. Add pasta and toss together, top with bacon and parmesan cheese. Add the remaining pasta water only as needed for moisture. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+3af7e0c33b783b780390247a1c4cedda",
#     "title" : "Bowtie Pasta and Peas With Bacon",
#     "sourceUrl" : "http://www.food.com/recipe/bowtie-pasta-and-peas-with-bacon-481359",
#     "requirementList" : [ {
#       "uniqueId" : "0b07ac3d-fb2f-473a-bf3d-6a6c48e9db8c",
#       "type" : "HARDWARE",
#       "name" : "4 slices bacon, cooked and chopped"
#     }, {
#       "uniqueId" : "8f1b5a80-8420-4f6d-a776-cabaff23d79c",
#       "type" : "HARDWARE",
#       "name" : "1 lb bow tie pasta"
#     }, {
#       "uniqueId" : "c749c01f-0536-4e91-9cf0-0eb090ef16fa",
#       "type" : "HARDWARE",
#       "name" : "2 pinches salt for the pasta water"
#     }, {
#       "uniqueId" : "7c39671c-8169-4de5-a5a2-32f430ac435e",
#       "type" : "HARDWARE",
#       "name" : "1 tablespoon oil"
#     }, {
#       "uniqueId" : "38e81c43-c264-4d89-b007-430c223fca75",
#       "type" : "HARDWARE",
#       "name" : "1 onion, chopped"
#     }, {
#       "uniqueId" : "a7197bba-4135-42a0-8554-5ba3d0b85d00",
#       "type" : "HARDWARE",
#       "name" : "4 garlic cloves, minced"
#     }, {
#       "uniqueId" : "9490ebc5-4678-49f8-8eda-8bf614d8dedf",
#       "type" : "HARDWARE",
#       "name" : "1 cup of pasta water"
#     }, {
#       "uniqueId" : "043dfaeb-b16d-4469-b55a-b2ce9441b8aa",
#       "type" : "HARDWARE",
#       "name" : "1 tablespoon parsley, chopped"
#     }, {
#       "uniqueId" : "9b383f47-13df-458b-bd3c-8005e935f5a9",
#       "type" : "HARDWARE",
#       "name" : "salt and pepper, to taste"
#     }, {
#       "uniqueId" : "91d71abe-997a-48cd-ba2f-fea542b19ee2",
#       "type" : "HARDWARE",
#       "name" : "cajun seasoning or creole seasoning, to taste"
#     }, {
#       "uniqueId" : "61257699-ff9e-412c-a5b1-e1f826c87ab1",
#       "type" : "HARDWARE",
#       "name" : "23 cup half-and-half"
#     }, {
#       "uniqueId" : "4640ee53-a075-4978-bb8d-5157e3bdee94",
#       "type" : "HARDWARE",
#       "name" : "1 (15 ounce) can lasueur early peas, drained"
#     }, {
#       "uniqueId" : "a7bac995-589d-49a5-91cc-3cb44d64293e",
#       "type" : "HARDWARE",
#       "name" : "12 cup parmesan cheese, grated"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "8f984cdb-bce8-49dd-9b70-f69d11f9fc01",
#       "response" : {
#         "speechText" : "Cook the bacon and chop; set aside.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook the bacon and chop; set aside." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "36e494e4-ab00-4323-9b24-5ba9c4bfdacf",
#       "response" : {
#         "speechText" : "In a large pot add two big pinches of salt to boiling water for pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "In a large pot add two big pinches of salt to boiling water for pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "dae2660e-aec2-4725-9f1f-a37ded375a27",
#       "response" : {
#         "speechText" : "Cook pasta according to package directions.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook pasta according to package directions." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "627a97fb-4825-4783-9a6e-7da08e4596f0",
#       "response" : {
#         "speechText" : "Reserve 1 cup of the pasta water before draining the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Reserve 1 cup of the pasta water before draining the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "60aead83-c502-445e-a2cf-c876d2ad4dde",
#       "response" : {
#         "speechText" : "When pasta is just about ready, in the pan you cooked bacon in add oil and heat over medium heat, saute the onion until soft, but not browned, about 4 minutes.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "When pasta is just about ready, in the pan you cooked bacon in add oil and heat over medium heat, saute the onion until soft, but not browned, about 4 minutes." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "35fdddc4-a5b3-4431-8e6c-f33987415567",
#       "response" : {
#         "speechText" : "Add the garlic and cook another minute.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the garlic and cook another minute." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "b38872e7-5c01-4fa3-a7c0-c03605595294",
#       "response" : {
#         "speechText" : "Stir in one cup of the pasta water and the parsley, salt, pepper, Cajun seasoning and half and half; bring to a boil.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Stir in one cup of the pasta water and the parsley, salt, pepper, Cajun seasoning and half and half; bring to a boil." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "70045bc6-b0bb-4cc1-a12f-dde9400ef65c",
#       "response" : {
#         "speechText" : "Add the peas, reduce heat and simmer just until the peas are warmed through.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the peas, reduce heat and simmer just until the peas are warmed through." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "d9e5ddb3-e8fc-43b5-bfdc-2543dcb3449e",
#       "response" : {
#         "speechText" : "Taste and adjust seasonings.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Taste and adjust seasonings." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "82405d47-3365-4394-9072-cb79e78a584a",
#       "response" : {
#         "speechText" : "Add pasta and toss together, top with bacon and parmesan cheese.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
# ...
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "2a74134a-e688-4380-bb18-859def5d2ff6",
#       "response" : {
#         "speechText" : "Attach a tag with cooking instructions: In a large kettle, brown 1 pound ground beef, or stew beef cut into bite-sized pieces, in a little olive oil.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Attach a tag with cooking instructions: In a large kettle, brown 1 pound ground beef, or stew beef cut into bite-sized pieces, in a little olive oil." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "f1400c4b-aea6-4ec3-b41d-de9e50a529e4",
#       "response" : {
#         "speechText" : "Remove tricolored pasta from top of jar and reserve.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Remove tricolored pasta from top of jar and reserve." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "73ca199c-6a24-4bf8-82e3-f0a9191bacca",
#       "response" : {
#         "speechText" : "Add the rest of the jar contents to the kettle with 12 cups water.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the rest of the jar contents to the kettle with 12 cups water." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "5816843a-ac92-4238-b714-9174d8b6ae50",
#       "response" : {
#         "speechText" : "Let it come to a boil and simmer 45 minutes.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Let it come to a boil and simmer 45 minutes." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "2a74134a-e688-4380-bb18-859def5d2ff6",
#       "idTo" : "f1400c4b-aea6-4ec3-b41d-de9e50a529e4"
#     }, {
#       "idFrom" : "2e43498d-66b3-4b7c-ba7e-fd3a37558cc4",
#       "idTo" : "2a74134a-e688-4380-bb18-859def5d2ff6"
#     }, {
#       "idFrom" : "73ca199c-6a24-4bf8-82e3-f0a9191bacca",
#       "idTo" : "5816843a-ac92-4238-b714-9174d8b6ae50"
#     }, {
#       "idFrom" : "f3c55ca9-414b-4747-acf3-140e42021321",
#       "idTo" : "e64f4dc6-7e1d-4993-9ff3-7926d2c5e1bd"
#     }, {
#       "idFrom" : "e64f4dc6-7e1d-4993-9ff3-7926d2c5e1bd",
#       "idTo" : "2e43498d-66b3-4b7c-ba7e-fd3a37558cc4"
#     }, {
#       "idFrom" : "af3bce30-d364-43a5-980d-6083f94bef98",
#       "idTo" : "f3c55ca9-414b-4747-acf3-140e42021321"
#     }, {
#       "idFrom" : "f1400c4b-aea6-4ec3-b41d-de9e50a529e4",
#       "idTo" : "73ca199c-6a24-4bf8-82e3-f0a9191bacca"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
#  9 cooking+recipe1m+a0b134dfb63895b5820dc7f04c158dfc 2.81480 {
#   "id" : "cooking+recipe1m+a0b134dfb63895b5820dc7f04c158dfc",
#   "contents" : "Spinach and blue cheese pasta. 400 g lasagna pasta or 400 g similar pasta 5 tablespoons olive oil 1 shallot 2 cloves garlic 400 g deep freeze spinach, defrosted 100 ml cream black pepper 8 pitted black olives 175 g blue cheese Chop the shallots, garlic and olives. Cook the pasta. While heating water for the pasta, heat 3 tbsp of oil in a skillet and saute the shallots and garlic circa 3 mins. Add the spinach and heat it slowly. Add the cream. Add salt and pepper to taste. Drain the pasta thoroughly and add pasta and olives to spinach mixture. Crumble the cheese over the pasta; stir. Drizzle rest of oil over pasta and add a generous amount of freshly ground pepper. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+a0b134dfb63895b5820dc7f04c158dfc",
#     "title" : "Spinach and blue cheese pasta",
#     "sourceUrl" : "http://www.food.com/recipe/spinach-and-blue-cheese-pasta-73683",
#     "requirementList" : [ {
#       "uniqueId" : "57bdc16c-2857-410d-b42e-181042d5ab8f",
#       "type" : "HARDWARE",
#       "name" : "400 g lasagna pasta or 400 g similar pasta"
#     }, {
#       "uniqueId" : "27bced3c-4581-4b61-92f2-23f5c3fdbd5c",
#       "type" : "HARDWARE",
#       "name" : "5 tablespoons olive oil"
#     }, {
#       "uniqueId" : "0d56e1ff-8b5e-4780-99aa-6571a5fe2a5c",
#       "type" : "HARDWARE",
#       "name" : "1 shallot"
#     }, {
#       "uniqueId" : "c0911646-0a53-44a9-bd3e-869bd9e7093b",
#       "type" : "HARDWARE",
#       "name" : "2 cloves garlic"
#     }, {
#       "uniqueId" : "04a51870-e4e2-4deb-8421-e5eb0312dada",
#       "type" : "HARDWARE",
#       "name" : "400 g deep freeze spinach, defrosted"
#     }, {
#       "uniqueId" : "4fe3a4e9-27d9-4177-b3c8-8fa1ca76a553",
#       "type" : "HARDWARE",
#       "name" : "100 ml cream"
#     }, {
#       "uniqueId" : "eea5da5d-4f46-4a60-860f-c7cbfbb60ec8",
#       "type" : "HARDWARE",
#       "name" : "black pepper"
#     }, {
#       "uniqueId" : "69db2f7f-e624-4af3-9111-41f2cd4c01a0",
#       "type" : "HARDWARE",
#       "name" : "8 pitted black olives"
#     }, {
#       "uniqueId" : "f545706e-ab17-4b7f-8d08-d238bcd93143",
#       "type" : "HARDWARE",
#       "name" : "175 g blue cheese"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "6beaf731-d7c2-4884-8d23-7ce1e4a2004e",
#       "response" : {
#         "speechText" : "Chop the shallots, garlic and olives.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Chop the shallots, garlic and olives." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "f6b24370-28f0-45d8-ab75-d480ce753966",
#       "response" : {
#         "speechText" : "Cook the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "27660996-7bca-4d7f-9f3f-d81c8edbe269",
#       "response" : {
#         "speechText" : "While heating water for the pasta, heat 3 tbsp of oil in a skillet and saute the shallots and garlic circa 3 mins.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "While heating water for the pasta, heat 3 tbsp of oil in a skillet and saute the shallots and garlic circa 3 mins." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "61c8697b-460c-45e7-9218-9e6ba67d5ee4",
#       "response" : {
#         "speechText" : "Add the spinach and heat it slowly.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the spinach and heat it slowly." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "7e2de2de-d199-430a-ac86-ad550055539e",
#       "response" : {
#         "speechText" : "Add the cream.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the cream." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "4a393184-573b-4311-bbe4-a0ba886dee71",
#       "response" : {
#         "speechText" : "Add salt and pepper to taste.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add salt and pepper to taste." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "5034f0a1-2747-4d85-aca1-5ee68cf88d7c",
#       "response" : {
#         "speechText" : "Drain the pasta thoroughly and add pasta and olives to spinach mixture.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Drain the pasta thoroughly and add pasta and olives to spinach mixture." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "3611ee6c-a2d8-434b-9922-c4d1f2813958",
#       "response" : {
#         "speechText" : "Crumble the cheese over the pasta; stir.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Crumble the cheese over the pasta; stir." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "87c2cf6f-f4be-4d15-b7ea-1a48296570cf",
#       "response" : {
#         "speechText" : "Drizzle rest of oil over pasta and add a generous amount of freshly ground pepper.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Drizzle rest of oil over pasta and add a generous amount of freshly ground pepper." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "3611ee6c-a2d8-434b-9922-c4d1f2813958",
#       "idTo" : "87c2cf6f-f4be-4d15-b7ea-1a48296570cf"
#     }, {
#       "idFrom" : "27660996-7bca-4d7f-9f3f-d81c8edbe269",
#       "idTo" : "61c8697b-460c-45e7-9218-9e6ba67d5ee4"
#     }, {
#       "idFrom" : "61c8697b-460c-45e7-9218-9e6ba67d5ee4",
#       "idTo" : "7e2de2de-d199-430a-ac86-ad550055539e"
#     }, {
#       "idFrom" : "4a393184-573b-4311-bbe4-a0ba886dee71",
#       "idTo" : "5034f0a1-2747-4d85-aca1-5ee68cf88d7c"
#     }, {
#       "idFrom" : "7e2de2de-d199-430a-ac86-ad550055539e",
#       "idTo" : "4a393184-573b-4311-bbe4-a0ba886dee71"
#     }, {
#       "idFrom" : "5034f0a1-2747-4d85-aca1-5ee68cf88d7c",
#       "idTo" : "3611ee6c-a2d8-434b-9922-c4d1f2813958"
#     }, {
#       "idFrom" : "f6b24370-28f0-45d8-ab75-d480ce753966",
#       "idTo" : "27660996-7bca-4d7f-9f3f-d81c8edbe269"
#     }, {
#       "idFrom" : "6beaf731-d7c2-4884-8d23-7ce1e4a2004e",
#       "idTo" : "f6b24370-28f0-45d8-ab75-d480ce753966"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
# 10 cooking+recipe1m+a5ee5b023bd2a32950b6e012b7f6be64 2.81200 {
#   "id" : "cooking+recipe1m+a5ee5b023bd2a32950b6e012b7f6be64",
#   "contents" : "Pasta Cacio E Pepe. 1 pound dried pasta 1/2 cup extra-virgin olive oil 1 tablespoon plus 1 teaspoon fresh coarsely ground black pepper, plus more to taste 1/4 cup Parmigiano-Reggiano, freshly grated 1/4 cup Pecorino Romano, freshly grated Fill a pasta pot or a large stockpot with 6 quarts of water, add 6 tablespoons of salt, and bring the water to a boil over high heat. If you are not using a pasta pot, put a colander in the sink or have a wire strainer handy to lift the pasta out of the pot. Drop the pasta into the boiling water, stir to prevent it from sticking together, partially cover the pot so the water returns to a boil quickly and continues boiling and cook the pasta until its al dente. While the pasta is cooking, combine the olive oil, pepper, and 1/2 cup of the pasta cooking water in a large saute pan. About 1 minute before the pasta is done, place the sauce over high heat. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+a5ee5b023bd2a32950b6e012b7f6be64",
#     "title" : "Pasta Cacio E Pepe",
#     "sourceUrl" : "http://www.foodrepublic.com/recipes/pasta-cacio-e-pepe-recipe/",
#     "requirementList" : [ {
#       "uniqueId" : "5e44b8c0-7d2f-474c-8d67-1aa86b1d166f",
#       "type" : "HARDWARE",
#       "name" : "1 pound dried pasta"
#     }, {
#       "uniqueId" : "9ffcc903-5cfd-4f00-825d-1e33d7f4978e",
#       "type" : "HARDWARE",
#       "name" : "1/2 cup extra-virgin olive oil"
#     }, {
#       "uniqueId" : "9047f355-473d-4a10-9e40-a88425457144",
#       "type" : "HARDWARE",
#       "name" : "1 tablespoon plus 1 teaspoon fresh coarsely ground black pepper, plus more to taste"
#     }, {
#       "uniqueId" : "65ffa78b-da5a-4b50-b4a4-c45a771b4640",
#       "type" : "HARDWARE",
#       "name" : "1/4 cup Parmigiano-Reggiano, freshly grated"
#     }, {
#       "uniqueId" : "870751fd-fdcf-4cdd-92c9-3114b81f6beb",
#       "type" : "HARDWARE",
#       "name" : "1/4 cup Pecorino Romano, freshly grated"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "a820dd41-d2cc-4cfe-9a69-a6558b98e434",
#       "response" : {
#         "speechText" : "Fill a pasta pot or a large stockpot with 6 quarts of water, add 6 tablespoons of salt, and bring the water to a boil over high heat.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Fill a pasta pot or a large stockpot with 6 quarts of water, add 6 tablespoons of salt, and bring the water to a boil over high heat." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "f0a3be67-5d70-4ef1-bc9c-dce35deed4b0",
#       "response" : {
#         "speechText" : "If you are not using a pasta pot, put a colander in the sink or have a wire strainer handy to lift the pasta out of the pot.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "If you are not using a pasta pot, put a colander in the sink or have a wire strainer handy to lift the pasta out of the pot." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "3a102e73-236e-462c-85b1-8ced26e387b1",
#       "response" : {
#         "speechText" : "Drop the pasta into the boiling water, stir to prevent it from sticking together, partially cover the pot so the water returns to a boil quickly and continues boiling and cook the pasta until its al dente.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Drop the pasta into the boiling water, stir to prevent it from sticking together, partially cover the pot so the water returns to a boil quickly and continues boiling and cook the pasta until its al dente." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "6dc50889-fc22-4263-a5a8-477e33708788",
#       "response" : {
#         "speechText" : "While the pasta is cooking, combine the olive oil, pepper, and 1/2 cup of the pasta cooking water in a large saute pan.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "While the pasta is cooking, combine the olive oil, pepper, and 1/2 cup of the pasta cooking water in a large saute pan." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "91dbdd75-6cd2-47bd-9933-22e155033472",
#       "response" : {
#         "speechText" : "About 1 minute before the pasta is done, place the sauce over high heat.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "About 1 minute before the pasta is done, place the sauce over high heat." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "6dc50889-fc22-4263-a5a8-477e33708788",
#       "idTo" : "91dbdd75-6cd2-47bd-9933-22e155033472"
#     }, {
#       "idFrom" : "3a102e73-236e-462c-85b1-8ced26e387b1",
#       "idTo" : "6dc50889-fc22-4263-a5a8-477e33708788"
#     }, {
#       "idFrom" : "a820dd41-d2cc-4cfe-9a69-a6558b98e434",
#       "idTo" : "f0a3be67-5d70-4ef1-bc9c-dce35deed4b0"
#     }, {
#       "idFrom" : "f0a3be67-5d70-4ef1-bc9c-dce35deed4b0",
#       "idTo" : "3a102e73-236e-462c-85b1-8ced26e387b1"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "foodrepublic"
#   }
# }

# %%
reranked = reranker.rerank(query, texts)
for i in range(0, 10):
    print(f'{i+1:2} {reranked[i].metadata["docid"]:15} {reranked[i].score:.5f} {reranked[i].text}')
# Out:
#  1 cooking+recipe1m+0e53f5660777a767609d56ff2694bb5c -0.58902 {
#   "id" : "cooking+recipe1m+0e53f5660777a767609d56ff2694bb5c",
#   "contents" : "Pasta with Spinach and Sausage. 1/2 pounds Gluten-free Pasta (I Used Macaroni) 1/2 pounds Wheat Pasta 1 Tablespoon Olive Oil 1 whole Onion, Minced 3 cloves Garlic, Thinly Sliced 1 pound Ground Sausage 3 cups Spinach, Chopped 1/4 cups Asiago Cheese, Shredded Fill 2 pots with water and bring to a boil. When water is boiling add the gluten-free pasta to one pot and the wheat pasta to the other. Cook each pasta according to the time listed on the package. If/when you stir the pasta, be sure to use a separate spoon for each pot. Drain pasta when it has finished cooking (I drain the gluten-free pasta in a colander and the wheat pasta using the lid of the pan it was cooked in to avoid contamination) and return each to their respective pot. While the pasta is cooking, heat the olive oil in a large skillet over medium heat. Add the onion and garlic and saute for 3 or 4 minutes, or until the onion is soft. Add the sausage into the skillet and brown it, breaking it up into small bits as it cooks. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+0e53f5660777a767609d56ff2694bb5c",
#     "title" : "Pasta with Spinach and Sausage",
#     "sourceUrl" : "http://tastykitchen.com/recipes/main-courses/pasta-with-spinach-and-sausage/",
#     "requirementList" : [ {
#       "uniqueId" : "90422e95-160f-446b-bb94-4ea2982afc7f",
#       "type" : "HARDWARE",
#       "name" : "1/2 pounds Gluten-free Pasta (I Used Macaroni)"
#     }, {
#       "uniqueId" : "f049434d-3d0c-400d-8525-27853b2e47a8",
#       "type" : "HARDWARE",
#       "name" : "1/2 pounds Wheat Pasta"
#     }, {
#       "uniqueId" : "83a1a7c0-3530-4c5a-8ccd-fa5e5598f595",
#       "type" : "HARDWARE",
#       "name" : "1 Tablespoon Olive Oil"
#     }, {
#       "uniqueId" : "928c2e67-fcd5-432e-96cb-1a3395ab47a4",
#       "type" : "HARDWARE",
#       "name" : "1 whole Onion, Minced"
#     }, {
#       "uniqueId" : "8f83677d-70f0-4333-b0e0-4ae14eec2375",
#       "type" : "HARDWARE",
#       "name" : "3 cloves Garlic, Thinly Sliced"
#     }, {
#       "uniqueId" : "64a2de3f-fa3f-4b61-ac19-b60068d9b3cb",
#       "type" : "HARDWARE",
#       "name" : "1 pound Ground Sausage"
#     }, {
#       "uniqueId" : "ce65708f-758d-44e0-8d5c-7d3d63159759",
#       "type" : "HARDWARE",
#       "name" : "3 cups Spinach, Chopped"
#     }, {
#       "uniqueId" : "5dc208ee-5d1c-44ca-bf62-22a16e88ab56",
#       "type" : "HARDWARE",
#       "name" : "1/4 cups Asiago Cheese, Shredded"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "281aa6f9-db22-45db-8a7f-bfeb5c4ccbe2",
#       "response" : {
#         "speechText" : "Fill 2 pots with water and bring to a boil.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Fill 2 pots with water and bring to a boil." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "7bd5e43b-0363-48a9-bc48-8128e3afbbf3",
#       "response" : {
#         "speechText" : "When water is boiling add the gluten-free pasta to one pot and the wheat pasta to the other.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "When water is boiling add the gluten-free pasta to one pot and the wheat pasta to the other." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "fa3a3487-8274-4dc7-844c-b2f8ff81cca9",
#       "response" : {
#         "speechText" : "Cook each pasta according to the time listed on the package.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook each pasta according to the time listed on the package." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "114eaedf-8783-459e-b72b-4644b4984a84",
#       "response" : {
#         "speechText" : "If/when you stir the pasta, be sure to use a separate spoon for each pot.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "If/when you stir the pasta, be sure to use a separate spoon for each pot." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "399f69db-034a-4e25-b1d4-98345439d3e7",
#       "response" : {
#         "speechText" : "Drain pasta when it has finished cooking (I drain the gluten-free pasta in a colander and the wheat pasta using the lid of the pan it was cooked in to avoid contamination) and return each to their respective pot.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Drain pasta when it has finished cooking (I drain the gluten-free pasta in a colander and the wheat pasta using the lid of the pan it was cooked in to avoid contamination) and return each to their respective pot." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "28e4aa62-c0f5-4da6-befc-017a2798da91",
#       "response" : {
#         "speechText" : "While the pasta is cooking, heat the olive oil in a large skillet over medium heat.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "While the pasta is cooking, heat the olive oil in a large skillet over medium heat." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "d1b03db4-59c1-483f-9a51-811e402d95aa",
#       "response" : {
#         "speechText" : "Add the onion and garlic and saute for 3 or 4 minutes, or until the onion is soft.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the onion and garlic and saute for 3 or 4 minutes, or until the onion is soft." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "4075a454-7863-4cfe-87a1-8a119feb721f",
#       "response" : {
#         "speechText" : "Add the sausage into the skillet and brown it, breaking it up into small bits as it cooks.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the sausage into the skillet and brown it, breaking it up into small bits as it cooks." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "fa3a3487-8274-4dc7-844c-b2f8ff81cca9",
#       "idTo" : "114eaedf-8783-459e-b72b-4644b4984a84"
#     }, {
#       "idFrom" : "281aa6f9-db22-45db-8a7f-bfeb5c4ccbe2",
#       "idTo" : "7bd5e43b-0363-48a9-bc48-8128e3afbbf3"
#     }, {
#       "idFrom" : "28e4aa62-c0f5-4da6-befc-017a2798da91",
#       "idTo" : "d1b03db4-59c1-483f-9a51-811e402d95aa"
#     }, {
#       "idFrom" : "7bd5e43b-0363-48a9-bc48-8128e3afbbf3",
#       "idTo" : "fa3a3487-8274-4dc7-844c-b2f8ff81cca9"
#     }, {
#       "idFrom" : "d1b03db4-59c1-483f-9a51-811e402d95aa",
#       "idTo" : "4075a454-7863-4cfe-87a1-8a119feb721f"
#     }, {
#       "idFrom" : "399f69db-034a-4e25-b1d4-98345439d3e7",
#       "idTo" : "28e4aa62-c0f5-4da6-befc-017a2798da91"
#     }, {
#       "idFrom" : "114eaedf-8783-459e-b72b-4644b4984a84",
#       "idTo" : "399f69db-034a-4e25-b1d4-98345439d3e7"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "tastykitchen.com"
#   }
# }
#  2 cooking+recipe1m+a5ee5b023bd2a32950b6e012b7f6be64 -0.59687 {
#   "id" : "cooking+recipe1m+a5ee5b023bd2a32950b6e012b7f6be64",
#   "contents" : "Pasta Cacio E Pepe. 1 pound dried pasta 1/2 cup extra-virgin olive oil 1 tablespoon plus 1 teaspoon fresh coarsely ground black pepper, plus more to taste 1/4 cup Parmigiano-Reggiano, freshly grated 1/4 cup Pecorino Romano, freshly grated Fill a pasta pot or a large stockpot with 6 quarts of water, add 6 tablespoons of salt, and bring the water to a boil over high heat. If you are not using a pasta pot, put a colander in the sink or have a wire strainer handy to lift the pasta out of the pot. Drop the pasta into the boiling water, stir to prevent it from sticking together, partially cover the pot so the water returns to a boil quickly and continues boiling and cook the pasta until its al dente. While the pasta is cooking, combine the olive oil, pepper, and 1/2 cup of the pasta cooking water in a large saute pan. About 1 minute before the pasta is done, place the sauce over high heat. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+a5ee5b023bd2a32950b6e012b7f6be64",
#     "title" : "Pasta Cacio E Pepe",
#     "sourceUrl" : "http://www.foodrepublic.com/recipes/pasta-cacio-e-pepe-recipe/",
#     "requirementList" : [ {
#       "uniqueId" : "5e44b8c0-7d2f-474c-8d67-1aa86b1d166f",
#       "type" : "HARDWARE",
#       "name" : "1 pound dried pasta"
#     }, {
#       "uniqueId" : "9ffcc903-5cfd-4f00-825d-1e33d7f4978e",
#       "type" : "HARDWARE",
#       "name" : "1/2 cup extra-virgin olive oil"
#     }, {
#       "uniqueId" : "9047f355-473d-4a10-9e40-a88425457144",
#       "type" : "HARDWARE",
#       "name" : "1 tablespoon plus 1 teaspoon fresh coarsely ground black pepper, plus more to taste"
#     }, {
#       "uniqueId" : "65ffa78b-da5a-4b50-b4a4-c45a771b4640",
#       "type" : "HARDWARE",
#       "name" : "1/4 cup Parmigiano-Reggiano, freshly grated"
#     }, {
#       "uniqueId" : "870751fd-fdcf-4cdd-92c9-3114b81f6beb",
#       "type" : "HARDWARE",
#       "name" : "1/4 cup Pecorino Romano, freshly grated"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "a820dd41-d2cc-4cfe-9a69-a6558b98e434",
#       "response" : {
#         "speechText" : "Fill a pasta pot or a large stockpot with 6 quarts of water, add 6 tablespoons of salt, and bring the water to a boil over high heat.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Fill a pasta pot or a large stockpot with 6 quarts of water, add 6 tablespoons of salt, and bring the water to a boil over high heat." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "f0a3be67-5d70-4ef1-bc9c-dce35deed4b0",
#       "response" : {
#         "speechText" : "If you are not using a pasta pot, put a colander in the sink or have a wire strainer handy to lift the pasta out of the pot.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "If you are not using a pasta pot, put a colander in the sink or have a wire strainer handy to lift the pasta out of the pot." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "3a102e73-236e-462c-85b1-8ced26e387b1",
#       "response" : {
#         "speechText" : "Drop the pasta into the boiling water, stir to prevent it from sticking together, partially cover the pot so the water returns to a boil quickly and continues boiling and cook the pasta until its al dente.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Drop the pasta into the boiling water, stir to prevent it from sticking together, partially cover the pot so the water returns to a boil quickly and continues boiling and cook the pasta until its al dente." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "6dc50889-fc22-4263-a5a8-477e33708788",
#       "response" : {
#         "speechText" : "While the pasta is cooking, combine the olive oil, pepper, and 1/2 cup of the pasta cooking water in a large saute pan.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "While the pasta is cooking, combine the olive oil, pepper, and 1/2 cup of the pasta cooking water in a large saute pan." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "91dbdd75-6cd2-47bd-9933-22e155033472",
#       "response" : {
#         "speechText" : "About 1 minute before the pasta is done, place the sauce over high heat.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "About 1 minute before the pasta is done, place the sauce over high heat." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "6dc50889-fc22-4263-a5a8-477e33708788",
#       "idTo" : "91dbdd75-6cd2-47bd-9933-22e155033472"
#     }, {
#       "idFrom" : "3a102e73-236e-462c-85b1-8ced26e387b1",
#       "idTo" : "6dc50889-fc22-4263-a5a8-477e33708788"
#     }, {
#       "idFrom" : "a820dd41-d2cc-4cfe-9a69-a6558b98e434",
#       "idTo" : "f0a3be67-5d70-4ef1-bc9c-dce35deed4b0"
#     }, {
#       "idFrom" : "f0a3be67-5d70-4ef1-bc9c-dce35deed4b0",
#       "idTo" : "3a102e73-236e-462c-85b1-8ced26e387b1"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "foodrepublic"
#   }
# }
#  3 cooking+recipe1m+81d98be9084ffad15fd31bbca9a62fd4 -0.70300 {
#   "id" : "cooking+recipe1m+81d98be9084ffad15fd31bbca9a62fd4",
#   "contents" : "Pasta Carbonara With Sweet Peas. 8 ounces penne pasta (or other tubular pasta) 12 cup thick slab bacon, diced 12 cup onion, chopped 1 garlic clove, sliced 14 cup heavy cream 14 teaspoon crushed red pepper flakes 14 teaspoon ground nutmeg 2 egg yolks 1 cup green peas (fresh or frozen) 12 teaspoon fresh ground black pepper 12 cup parmesan cheese, grated Boil pasta in salted water. Meanwhile render diced bacon. Shortly before it's completely rendered, add chopped onion and garlic slices. Cook until the onion is soft and add cream, pepper flakes, and nutmeg. When the pasta is cooked, transfer the pasta with a slotted spoon or large sieve directly from the pasta pot to the pan with the bacon. Do not drain the pasta first; you want some of the pasta water in the dish. Add the peas to the hot pasta water to blanch. Turn off the fire under the pasta and bacon mixture and add the eggs, stirring to thoroughly coat each pasta tube with the egg. Take care not to allow the egg yolks to scramble at the bottom of the pan. Transfer the peas with the slotted spoon or sieve from the pasta water to the pan along with the black pepper and parmesan. Continue to stir. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+81d98be9084ffad15fd31bbca9a62fd4",
#     "title" : "Pasta Carbonara With Sweet Peas",
#     "sourceUrl" : "http://www.food.com/recipe/pasta-carbonara-with-sweet-peas-503999",
#     "requirementList" : [ {
#       "uniqueId" : "099d5472-2c45-4123-ba04-b21c074ef4bb",
#       "type" : "HARDWARE",
#       "name" : "8 ounces penne pasta (or other tubular pasta)"
#     }, {
#       "uniqueId" : "54e8a5cc-cd99-4653-bbaa-18651de37397",
#       "type" : "HARDWARE",
#       "name" : "12 cup thick slab bacon, diced"
#     }, {
#       "uniqueId" : "b84744ec-17f0-4022-bbdc-b296f74f27a2",
#       "type" : "HARDWARE",
#       "name" : "12 cup onion, chopped"
#     }, {
#       "uniqueId" : "008ef86b-0491-4f28-88b2-fbc578431463",
#       "type" : "HARDWARE",
#       "name" : "1 garlic clove, sliced"
#     }, {
#       "uniqueId" : "6ea86bc3-2a61-4917-9ed9-622a13027878",
#       "type" : "HARDWARE",
#       "name" : "14 cup heavy cream"
#     }, {
#       "uniqueId" : "84f4377e-6b9a-4c11-809d-87eddb5640a6",
#       "type" : "HARDWARE",
#       "name" : "14 teaspoon crushed red pepper flakes"
#     }, {
#       "uniqueId" : "57f5ee49-ac9b-47b2-9fea-cb12a65577f3",
#       "type" : "HARDWARE",
#       "name" : "14 teaspoon ground nutmeg"
#     }, {
#       "uniqueId" : "7f7e4beb-71f5-463c-8da9-6d2ac38f021a",
#       "type" : "HARDWARE",
#       "name" : "2 egg yolks"
#     }, {
#       "uniqueId" : "c87a6e37-0314-420b-b7d5-7e285a976fc3",
#       "type" : "HARDWARE",
#       "name" : "1 cup green peas (fresh or frozen)"
#     }, {
#       "uniqueId" : "85eef49d-0a23-4cf0-87f8-fc15de40c029",
#       "type" : "HARDWARE",
#       "name" : "12 teaspoon fresh ground black pepper"
#     }, {
#       "uniqueId" : "7283cb98-cf29-42bd-896e-70286ab3a10d",
#       "type" : "HARDWARE",
#       "name" : "12 cup parmesan cheese, grated"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "30ec053e-74ff-48b8-9077-39c038387f9d",
#       "response" : {
#         "speechText" : "Boil pasta in salted water.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Boil pasta in salted water." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "1baa96e0-d677-4030-863e-95f5562cf823",
#       "response" : {
#         "speechText" : "Meanwhile render diced bacon.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Meanwhile render diced bacon." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "ba81132a-97a1-4a01-b1c2-c8cf28b635c3",
#       "response" : {
#         "speechText" : "Shortly before it's completely rendered, add chopped onion and garlic slices.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Shortly before it's completely rendered, add chopped onion and garlic slices." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "44ce30e7-9ecf-49e7-b035-1e473b498044",
#       "response" : {
#         "speechText" : "Cook until the onion is soft and add cream, pepper flakes, and nutmeg.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook until the onion is soft and add cream, pepper flakes, and nutmeg." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "ce94a98a-bc9b-4e12-8e15-08244326c1cf",
#       "response" : {
#         "speechText" : "When the pasta is cooked, transfer the pasta with a slotted spoon or large sieve directly from the pasta pot to the pan with the bacon.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "When the pasta is cooked, transfer the pasta with a slotted spoon or large sieve directly from the pasta pot to the pan with the bacon." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "82f91765-1548-4964-8a8d-1e99aa67edce",
#       "response" : {
#         "speechText" : "Do not drain the pasta first; you want some of the pasta water in the dish.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Do not drain the pasta first; you want some of the pasta water in the dish." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "00df6c22-d250-4439-8ad9-f8b087633974",
#       "response" : {
#         "speechText" : "Add the peas to the hot pasta water to blanch.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the peas to the hot pasta water to blanch." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "38dd2f83-4f3e-4a71-be1e-8956366d0ad5",
#       "response" : {
#         "speechText" : "Turn off the fire under the pasta and bacon mixture and add the eggs, stirring to thoroughly coat each pasta tube with the egg.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Turn off the fire under the pasta and bacon mixture and add the eggs, stirring to thoroughly coat each pasta tube with the egg." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "aabf2233-aadd-4935-9cea-38575d16efb5",
#       "response" : {
#         "speechText" : "Take care not to allow the egg yolks to scramble at the bottom of the pan.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Take care not to allow the egg yolks to scramble at the bottom of the pan." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "2529720e-348b-4295-8a8e-f1f96e9f5a20",
#       "response" : {
#         "speechText" : "Transfer the peas with the slotted spoon or sieve from the pasta water to the pan along with the black pepper and parmesan.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Transfer the peas with the slotted spoon or sieve from the pasta water to the pan along with the black pepper and parmesan." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "c0b80951-17f8-44a0-83b6-a06bba6c34d7",
#       "response" : {
#         "speechText" : "Continue to stir.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Continue to stir." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "00df6c22-d250-4439-8ad9-f8b087633974",
#       "idTo" : "38dd2f83-4f3e-4a71-be1e-8956366d0ad5"
#     }, {
#       "idFrom" : "82f91765-1548-4964-8a8d-1e99aa67edce",
#       "idTo" : "00df6c22-d250-4439-8ad9-f8b087633974"
#     }, {
#       "idFrom" : "ba81132a-97a1-4a01-b1c2-c8cf28b635c3",
#       "idTo" : "44ce30e7-9ecf-49e7-b035-1e473b498044"
#     }, {
#       "idFrom" : "2529720e-348b-4295-8a8e-f1f96e9f5a20",
#       "idTo" : "c0b80951-17f8-44a0-83b6-a06bba6c34d7"
#     }, {
#       "idFrom" : "44ce30e7-9ecf-49e7-b035-1e473b498044",
#       "idTo" : "ce94a98a-bc9b-4e12-8e15-08244326c1cf"
#     }, {
#       "idFrom" : "ce94a98a-bc9b-4e12-8e15-08244326c1cf",
#       "idTo" : "82f91765-1548-4964-8a8d-1e99aa67edce"
#     }, {
#       "idFrom" : "38dd2f83-4f3e-4a71-be1e-8956366d0ad5",
#       "idTo" : "aabf2233-aadd-4935-9cea-38575d16efb5"
#     }, {
#       "idFrom" : "aabf2233-aadd-4935-9cea-38575d16efb5",
#       "idTo" : "2529720e-348b-4295-8a8e-f1f96e9f5a20"
#     }, {
#       "idFrom" : "1baa96e0-d677-4030-863e-95f5562cf823",
#       "idTo" : "ba81132a-97a1-4a01-b1c2-c8cf28b635c3"
#     }, {
#       "idFrom" : "30ec053e-74ff-48b8-9077-39c038387f9d",
#       "idTo" : "1baa96e0-d677-4030-863e-95f5562cf823"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
#  4 cooking+recipe1m+a0b134dfb63895b5820dc7f04c158dfc -0.81977 {
#   "id" : "cooking+recipe1m+a0b134dfb63895b5820dc7f04c158dfc",
#   "contents" : "Spinach and blue cheese pasta. 400 g lasagna pasta or 400 g similar pasta 5 tablespoons olive oil 1 shallot 2 cloves garlic 400 g deep freeze spinach, defrosted 100 ml cream black pepper 8 pitted black olives 175 g blue cheese Chop the shallots, garlic and olives. Cook the pasta. While heating water for the pasta, heat 3 tbsp of oil in a skillet and saute the shallots and garlic circa 3 mins. Add the spinach and heat it slowly. Add the cream. Add salt and pepper to taste. Drain the pasta thoroughly and add pasta and olives to spinach mixture. Crumble the cheese over the pasta; stir. Drizzle rest of oil over pasta and add a generous amount of freshly ground pepper. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+a0b134dfb63895b5820dc7f04c158dfc",
#     "title" : "Spinach and blue cheese pasta",
#     "sourceUrl" : "http://www.food.com/recipe/spinach-and-blue-cheese-pasta-73683",
#     "requirementList" : [ {
#       "uniqueId" : "57bdc16c-2857-410d-b42e-181042d5ab8f",
#       "type" : "HARDWARE",
#       "name" : "400 g lasagna pasta or 400 g similar pasta"
#     }, {
#       "uniqueId" : "27bced3c-4581-4b61-92f2-23f5c3fdbd5c",
#       "type" : "HARDWARE",
#       "name" : "5 tablespoons olive oil"
#     }, {
#       "uniqueId" : "0d56e1ff-8b5e-4780-99aa-6571a5fe2a5c",
#       "type" : "HARDWARE",
#       "name" : "1 shallot"
#     }, {
#       "uniqueId" : "c0911646-0a53-44a9-bd3e-869bd9e7093b",
#       "type" : "HARDWARE",
#       "name" : "2 cloves garlic"
#     }, {
#       "uniqueId" : "04a51870-e4e2-4deb-8421-e5eb0312dada",
#       "type" : "HARDWARE",
#       "name" : "400 g deep freeze spinach, defrosted"
#     }, {
#       "uniqueId" : "4fe3a4e9-27d9-4177-b3c8-8fa1ca76a553",
#       "type" : "HARDWARE",
#       "name" : "100 ml cream"
#     }, {
#       "uniqueId" : "eea5da5d-4f46-4a60-860f-c7cbfbb60ec8",
#       "type" : "HARDWARE",
#       "name" : "black pepper"
#     }, {
#       "uniqueId" : "69db2f7f-e624-4af3-9111-41f2cd4c01a0",
#       "type" : "HARDWARE",
#       "name" : "8 pitted black olives"
#     }, {
#       "uniqueId" : "f545706e-ab17-4b7f-8d08-d238bcd93143",
#       "type" : "HARDWARE",
#       "name" : "175 g blue cheese"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "6beaf731-d7c2-4884-8d23-7ce1e4a2004e",
#       "response" : {
#         "speechText" : "Chop the shallots, garlic and olives.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Chop the shallots, garlic and olives." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "f6b24370-28f0-45d8-ab75-d480ce753966",
#       "response" : {
#         "speechText" : "Cook the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "27660996-7bca-4d7f-9f3f-d81c8edbe269",
#       "response" : {
#         "speechText" : "While heating water for the pasta, heat 3 tbsp of oil in a skillet and saute the shallots and garlic circa 3 mins.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "While heating water for the pasta, heat 3 tbsp of oil in a skillet and saute the shallots and garlic circa 3 mins." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "61c8697b-460c-45e7-9218-9e6ba67d5ee4",
#       "response" : {
#         "speechText" : "Add the spinach and heat it slowly.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the spinach and heat it slowly." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "7e2de2de-d199-430a-ac86-ad550055539e",
#       "response" : {
#         "speechText" : "Add the cream.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the cream." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "4a393184-573b-4311-bbe4-a0ba886dee71",
#       "response" : {
#         "speechText" : "Add salt and pepper to taste.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add salt and pepper to taste." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "5034f0a1-2747-4d85-aca1-5ee68cf88d7c",
#       "response" : {
#         "speechText" : "Drain the pasta thoroughly and add pasta and olives to spinach mixture.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Drain the pasta thoroughly and add pasta and olives to spinach mixture." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "3611ee6c-a2d8-434b-9922-c4d1f2813958",
#       "response" : {
#         "speechText" : "Crumble the cheese over the pasta; stir.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Crumble the cheese over the pasta; stir." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "87c2cf6f-f4be-4d15-b7ea-1a48296570cf",
#       "response" : {
#         "speechText" : "Drizzle rest of oil over pasta and add a generous amount of freshly ground pepper.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Drizzle rest of oil over pasta and add a generous amount of freshly ground pepper." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "3611ee6c-a2d8-434b-9922-c4d1f2813958",
#       "idTo" : "87c2cf6f-f4be-4d15-b7ea-1a48296570cf"
#     }, {
#       "idFrom" : "27660996-7bca-4d7f-9f3f-d81c8edbe269",
#       "idTo" : "61c8697b-460c-45e7-9218-9e6ba67d5ee4"
#     }, {
#       "idFrom" : "61c8697b-460c-45e7-9218-9e6ba67d5ee4",
#       "idTo" : "7e2de2de-d199-430a-ac86-ad550055539e"
#     }, {
#       "idFrom" : "4a393184-573b-4311-bbe4-a0ba886dee71",
#       "idTo" : "5034f0a1-2747-4d85-aca1-5ee68cf88d7c"
#     }, {
#       "idFrom" : "7e2de2de-d199-430a-ac86-ad550055539e",
#       "idTo" : "4a393184-573b-4311-bbe4-a0ba886dee71"
#     }, {
#       "idFrom" : "5034f0a1-2747-4d85-aca1-5ee68cf88d7c",
#       "idTo" : "3611ee6c-a2d8-434b-9922-c4d1f2813958"
#     }, {
#       "idFrom" : "f6b24370-28f0-45d8-ab75-d480ce753966",
#       "idTo" : "27660996-7bca-4d7f-9f3f-d81c8edbe269"
#     }, {
#       "idFrom" : "6beaf731-d7c2-4884-8d23-7ce1e4a2004e",
#       "idTo" : "f6b24370-28f0-45d8-ab75-d480ce753966"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
#  5 cooking+recipe1m+3af7e0c33b783b780390247a1c4cedda -0.97697 {
#   "id" : "cooking+recipe1m+3af7e0c33b783b780390247a1c4cedda",
#   "contents" : "Bowtie Pasta and Peas With Bacon. 4 slices bacon, cooked and chopped 1 lb bow tie pasta 2 pinches salt for the pasta water 1 tablespoon oil 1 onion, chopped 4 garlic cloves, minced 1 cup of pasta water 1 tablespoon parsley, chopped salt and pepper, to taste cajun seasoning or creole seasoning, to taste 23 cup half-and-half 1 (15 ounce) can lasueur early peas, drained 12 cup parmesan cheese, grated Cook the bacon and chop; set aside. In a large pot add two big pinches of salt to boiling water for pasta. Cook pasta according to package directions. Reserve 1 cup of the pasta water before draining the pasta. When pasta is just about ready, in the pan you cooked bacon in add oil and heat over medium heat, saute the onion until soft, but not browned, about 4 minutes. Add the garlic and cook another minute. Stir in one cup of the pasta water and the parsley, salt, pepper, Cajun seasoning and half and half; bring to a boil. Add the peas, reduce heat and simmer just until the peas are warmed through. Taste and adjust seasonings. Add pasta and toss together, top with bacon and parmesan cheese. Add the remaining pasta water only as needed for moisture. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+3af7e0c33b783b780390247a1c4cedda",
#     "title" : "Bowtie Pasta and Peas With Bacon",
#     "sourceUrl" : "http://www.food.com/recipe/bowtie-pasta-and-peas-with-bacon-481359",
#     "requirementList" : [ {
#       "uniqueId" : "0b07ac3d-fb2f-473a-bf3d-6a6c48e9db8c",
#       "type" : "HARDWARE",
#       "name" : "4 slices bacon, cooked and chopped"
#     }, {
#       "uniqueId" : "8f1b5a80-8420-4f6d-a776-cabaff23d79c",
#       "type" : "HARDWARE",
#       "name" : "1 lb bow tie pasta"
#     }, {
#       "uniqueId" : "c749c01f-0536-4e91-9cf0-0eb090ef16fa",
#       "type" : "HARDWARE",
#       "name" : "2 pinches salt for the pasta water"
#     }, {
#       "uniqueId" : "7c39671c-8169-4de5-a5a2-32f430ac435e",
#       "type" : "HARDWARE",
#       "name" : "1 tablespoon oil"
#     }, {
#       "uniqueId" : "38e81c43-c264-4d89-b007-430c223fca75",
#       "type" : "HARDWARE",
#       "name" : "1 onion, chopped"
#     }, {
#       "uniqueId" : "a7197bba-4135-42a0-8554-5ba3d0b85d00",
#       "type" : "HARDWARE",
#       "name" : "4 garlic cloves, minced"
#     }, {
#       "uniqueId" : "9490ebc5-4678-49f8-8eda-8bf614d8dedf",
#       "type" : "HARDWARE",
#       "name" : "1 cup of pasta water"
#     }, {
#       "uniqueId" : "043dfaeb-b16d-4469-b55a-b2ce9441b8aa",
#       "type" : "HARDWARE",
#       "name" : "1 tablespoon parsley, chopped"
#     }, {
#       "uniqueId" : "9b383f47-13df-458b-bd3c-8005e935f5a9",
#       "type" : "HARDWARE",
#       "name" : "salt and pepper, to taste"
#     }, {
#       "uniqueId" : "91d71abe-997a-48cd-ba2f-fea542b19ee2",
#       "type" : "HARDWARE",
#       "name" : "cajun seasoning or creole seasoning, to taste"
#     }, {
#       "uniqueId" : "61257699-ff9e-412c-a5b1-e1f826c87ab1",
#       "type" : "HARDWARE",
#       "name" : "23 cup half-and-half"
#     }, {
#       "uniqueId" : "4640ee53-a075-4978-bb8d-5157e3bdee94",
#       "type" : "HARDWARE",
#       "name" : "1 (15 ounce) can lasueur early peas, drained"
#     }, {
#       "uniqueId" : "a7bac995-589d-49a5-91cc-3cb44d64293e",
#       "type" : "HARDWARE",
#       "name" : "12 cup parmesan cheese, grated"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "8f984cdb-bce8-49dd-9b70-f69d11f9fc01",
#       "response" : {
#         "speechText" : "Cook the bacon and chop; set aside.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook the bacon and chop; set aside." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "36e494e4-ab00-4323-9b24-5ba9c4bfdacf",
#       "response" : {
#         "speechText" : "In a large pot add two big pinches of salt to boiling water for pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "In a large pot add two big pinches of salt to boiling water for pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "dae2660e-aec2-4725-9f1f-a37ded375a27",
#       "response" : {
#         "speechText" : "Cook pasta according to package directions.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cook pasta according to package directions." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "627a97fb-4825-4783-9a6e-7da08e4596f0",
#       "response" : {
#         "speechText" : "Reserve 1 cup of the pasta water before draining the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Reserve 1 cup of the pasta water before draining the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "60aead83-c502-445e-a2cf-c876d2ad4dde",
#       "response" : {
#         "speechText" : "When pasta is just about ready, in the pan you cooked bacon in add oil and heat over medium heat, saute the onion until soft, but not browned, about 4 minutes.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "When pasta is just about ready, in the pan you cooked bacon in add oil and heat over medium heat, saute the onion until soft, but not browned, about 4 minutes." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "35fdddc4-a5b3-4431-8e6c-f33987415567",
#       "response" : {
#         "speechText" : "Add the garlic and cook another minute.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the garlic and cook another minute." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "b38872e7-5c01-4fa3-a7c0-c03605595294",
#       "response" : {
#         "speechText" : "Stir in one cup of the pasta water and the parsley, salt, pepper, Cajun seasoning and half and half; bring to a boil.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Stir in one cup of the pasta water and the parsley, salt, pepper, Cajun seasoning and half and half; bring to a boil." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "70045bc6-b0bb-4cc1-a12f-dde9400ef65c",
#       "response" : {
#         "speechText" : "Add the peas, reduce heat and simmer just until the peas are warmed through.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the peas, reduce heat and simmer just until the peas are warmed through." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "d9e5ddb3-e8fc-43b5-bfdc-2543dcb3449e",
#       "response" : {
#         "speechText" : "Taste and adjust seasonings.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Taste and adjust seasonings." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "82405d47-3365-4394-9072-cb79e78a584a",
#       "response" : {
#         "speechText" : "Add pasta and toss together, top with bacon and parmesan cheese.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add pasta and toss together, top with bacon and parmesan cheese." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "c54ba6e9-70f7-4f71-8846-893f8213572b",
#       "response" : {
#         "speechText" : "Add the remaining pasta water only as needed for moisture.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the remaining pasta water only as needed for moisture." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "35fdddc4-a5b3-4431-8e6c-f33987415567",
#       "idTo" : "b38872e7-5c01-4fa3-a7c0-c03605595294"
#     }, {
#       "idFrom" : "70045bc6-b0bb-4cc1-a12f-dde9400ef65c",
#       "idTo" : "d9e5ddb3-e8fc-43b5-bfdc-2543dcb3449e"
#     }, {
#       "idFrom" : "d9e5ddb3-e8fc-43b5-bfdc-2543dcb3449e",
#       "idTo" : "82405d47-3365-4394-9072-cb79e78a584a"
#     }, {
#       "idFrom" : "dae2660e-aec2-4725-9f1f-a37ded375a27",
#       "idTo" : "627a97fb-4825-4783-9a6e-7da08e4596f0"
#     }, {
#       "idFrom" : "8f984cdb-bce8-49dd-9b70-f69d11f9fc01",
#       "idTo" : "36e494e4-ab00-4323-9b24-5ba9c4bfdacf"
#     }, {
#       "idFrom" : "627a97fb-4825-4783-9a6e-7da08e4596f0",
#       "idTo" : "60aead83-c502-445e-a2cf-c876d2ad4dde"
#     }, {
#       "idFrom" : "82405d47-3365-4394-9072-cb79e78a584a",
#       "idTo" : "c54ba6e9-70f7-4f71-8846-893f8213572b"
#     }, {
#       "idFrom" : "b38872e7-5c01-4fa3-a7c0-c03605595294",
#       "idTo" : "70045bc6-b0bb-4cc1-a12f-dde9400ef65c"
#     }, {
#       "idFrom" : "60aead83-c502-445e-a2cf-c876d2ad4dde",
#       "idTo" : "35fdddc4-a5b3-4431-8e6c-f33987415567"
#     }, {
#       "idFrom" : "36e494e4-ab00-4323-9b24-5ba9c4bfdacf",
#       "idTo" : "dae2660e-aec2-4725-9f1f-a37ded375a27"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
#  6 cooking+recipe1m+e913e7d20377b736080a0e7df5f7a37a -1.06737 {
#   "id" : "cooking+recipe1m+e913e7d20377b736080a0e7df5f7a37a",
#   "contents" : "Girls Night Pasta. 16 ounces, weight Rotini Pasta, Cooked 1 whole Roasted Chicken, Picked 1 cup Sun-Dried Tomatoes, Diced 1/2 cups Grated Parmesan Cheese 2 ounces, weight Pine Nuts, Toasted 1 cup Pesto Sauce (or To Taste) 1 cup Reserved Pasta Water (add To Taste) 2 dashes Salt And Pepper, to taste Start off by boiling some salted pasta water, and cook the pasta until almost al dente. Reserve 1 cup of pasta water, then drain the pasta and set it aside (the pasta will finish cooking when you stir in the other ingredients). Pick the chicken, dice the sundried tomatoes, and grate the Parmesan. Lightly toast the pine nuts in a skillet, watching carefully so that they dont burn. Over low heat, stir the pesto, tomatoes, chicken, and pine nuts into the pasta until incorporated and the pasta is al dente. If the pasta looks dry, add in a splash of pasta water. Keep adding pasta water until the consistency is to your taste. Season with salt and pepper. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+e913e7d20377b736080a0e7df5f7a37a",
#     "title" : "Girls Night Pasta",
#     "sourceUrl" : "http://tastykitchen.com/recipes/main-courses/girlse28099-night-pasta/",
#     "requirementList" : [ {
#       "uniqueId" : "50dba85d-ca27-4625-94e4-5d26844ec66f",
#       "type" : "HARDWARE",
#       "name" : "16 ounces, weight Rotini Pasta, Cooked"
#     }, {
#       "uniqueId" : "d5641538-5764-4446-9562-f7f4feaf28a7",
#       "type" : "HARDWARE",
#       "name" : "1 whole Roasted Chicken, Picked"
#     }, {
#       "uniqueId" : "4fb0e6ee-4923-4a3f-9e6a-9f01dc40323a",
#       "type" : "HARDWARE",
#       "name" : "1 cup Sun-Dried Tomatoes, Diced"
#     }, {
#       "uniqueId" : "225b9d8a-4900-4a18-895f-082b1692ea65",
#       "type" : "HARDWARE",
#       "name" : "1/2 cups Grated Parmesan Cheese"
#     }, {
#       "uniqueId" : "73f90831-ebcc-416f-98db-c36987181b4f",
#       "type" : "HARDWARE",
#       "name" : "2 ounces, weight Pine Nuts, Toasted"
#     }, {
#       "uniqueId" : "d2d059c9-08ed-4aed-9246-ca03decf2007",
#       "type" : "HARDWARE",
#       "name" : "1 cup Pesto Sauce (or To Taste)"
#     }, {
#       "uniqueId" : "d2f57306-cd4f-4b86-9b24-9db7c4bf18cc",
#       "type" : "HARDWARE",
#       "name" : "1 cup Reserved Pasta Water (add To Taste)"
#     }, {
#       "uniqueId" : "a4642e9f-fd72-43d5-ad3c-853aef39446b",
#       "type" : "HARDWARE",
#       "name" : "2 dashes Salt And Pepper, to taste"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "56655348-d182-4070-b102-56dd8c934479",
#       "response" : {
#         "speechText" : "Start off by boiling some salted pasta water, and cook the pasta until almost al dente.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Start off by boiling some salted pasta water, and cook the pasta until almost al dente." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "0a4d80fa-6c2e-43ad-9707-d820aa9a6645",
#       "response" : {
#         "speechText" : "Reserve 1 cup of pasta water, then drain the pasta and set it aside (the pasta will finish cooking when you stir in the other ingredients).",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Reserve 1 cup of pasta water, then drain the pasta and set it aside (the pasta will finish cooking when you stir in the other ingredients)." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "3f6f1de0-1212-4225-b7b3-619ccd5a75ca",
#       "response" : {
#         "speechText" : "Pick the chicken, dice the sundried tomatoes, and grate the Parmesan.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Pick the chicken, dice the sundried tomatoes, and grate the Parmesan." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "d9f58b16-574e-4b5d-8e87-8e611423aebc",
#       "response" : {
#         "speechText" : "Lightly toast the pine nuts in a skillet, watching carefully so that they dont burn.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Lightly toast the pine nuts in a skillet, watching carefully so that they dont burn." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "43769eb4-db3b-42fd-b7a0-27b39d8eda4e",
#       "response" : {
#         "speechText" : "Over low heat, stir the pesto, tomatoes, chicken, and pine nuts into the pasta until incorporated and the pasta is al dente.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Over low heat, stir the pesto, tomatoes, chicken, and pine nuts into the pasta until incorporated and the pasta is al dente." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "270e45eb-cc88-43bd-b986-a0675fdf11e9",
#       "response" : {
#         "speechText" : "If the pasta looks dry, add in a splash of pasta water.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "If the pasta looks dry, add in a splash of pasta water." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "e33c5d4c-2232-4f3f-88ca-1ec865394bf5",
#       "response" : {
#         "speechText" : "Keep adding pasta water until the consistency is to your taste.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Keep adding pasta water until the consistency is to your taste." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "82ca863b-382f-42e0-95a1-977c43a88198",
#       "response" : {
#         "speechText" : "Season with salt and pepper.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Season with salt and pepper." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "d9f58b16-574e-4b5d-8e87-8e611423aebc",
#       "idTo" : "43769eb4-db3b-42fd-b7a0-27b39d8eda4e"
#     }, {
#       "idFrom" : "43769eb4-db3b-42fd-b7a0-27b39d8eda4e",
#       "idTo" : "270e45eb-cc88-43bd-b986-a0675fdf11e9"
#     }, {
#       "idFrom" : "270e45eb-cc88-43bd-b986-a0675fdf11e9",
#       "idTo" : "e33c5d4c-2232-4f3f-88ca-1ec865394bf5"
#     }, {
#       "idFrom" : "0a4d80fa-6c2e-43ad-9707-d820aa9a6645",
#       "idTo" : "3f6f1de0-1212-4225-b7b3-619ccd5a75ca"
#     }, {
#       "idFrom" : "e33c5d4c-2232-4f3f-88ca-1ec865394bf5",
#       "idTo" : "82ca863b-382f-42e0-95a1-977c43a88198"
#     }, {
#       "idFrom" : "3f6f1de0-1212-4225-b7b3-619ccd5a75ca",
#       "idTo" : "d9f58b16-574e-4b5d-8e87-8e611423aebc"
#     }, {
#       "idFrom" : "56655348-d182-4070-b102-56dd8c934479",
#       "idTo" : "0a4d80fa-6c2e-43ad-9707-d820aa9a6645"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "tastykitchen.com"
#   }
# }
#  7 cooking+recipe1m+679e29e45c779244d693d52b67938144 -1.25758 {
#   "id" : "cooking+recipe1m+679e29e45c779244d693d52b67938144",
# ...
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the feta cheese, green olives, mild pepper rings, and sliced pepperoni to the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "bd824919-f844-40da-8c01-8ca766fde5ac",
#       "response" : {
#         "speechText" : "Chop Genoa Salami into bite size pieces and add to the pasta (you will want to have the deli to slice the salami on the thick side).",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Chop Genoa Salami into bite size pieces and add to the pasta (you will want to have the deli to slice the salami on the thick side)." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "e1a1eb64-7a54-4ac7-9cde-89420116e0be",
#       "response" : {
#         "speechText" : "Cut mozzarella cheese into small squares and add to the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Cut mozzarella cheese into small squares and add to the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "0bf4463b-6b79-41a9-8e93-7e40f15b914d",
#       "response" : {
#         "speechText" : "Add the McCormick Salad Supreme, sun-dried tomato pesto, and Italian dressing to the pasta salad.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the McCormick Salad Supreme, sun-dried tomato pesto, and Italian dressing to the pasta salad." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "9b6a6735-068a-4c6b-ad80-0d741485e688",
#       "response" : {
#         "speechText" : "Mix well after adding each ingredient.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Mix well after adding each ingredient." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "012ae70f-f5f1-4b81-9090-16f02cef75c9",
#       "response" : {
#         "speechText" : "Refrigerate for at least one or more hours to let all the flavors mix in to the pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Refrigerate for at least one or more hours to let all the flavors mix in to the pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "e1a1eb64-7a54-4ac7-9cde-89420116e0be",
#       "idTo" : "0bf4463b-6b79-41a9-8e93-7e40f15b914d"
#     }, {
#       "idFrom" : "0bf4463b-6b79-41a9-8e93-7e40f15b914d",
#       "idTo" : "9b6a6735-068a-4c6b-ad80-0d741485e688"
#     }, {
#       "idFrom" : "6b1d66b3-577e-4667-9c08-4477fd3f321b",
#       "idTo" : "9bb3bf34-c884-43e5-9fc2-e569028baf66"
#     }, {
#       "idFrom" : "9928123f-dea4-4f4d-9b05-7e4436ba058d",
#       "idTo" : "9f8165ca-d083-48f2-999f-978d6f5019d5"
#     }, {
#       "idFrom" : "bd824919-f844-40da-8c01-8ca766fde5ac",
#       "idTo" : "e1a1eb64-7a54-4ac7-9cde-89420116e0be"
#     }, {
#       "idFrom" : "9bb3bf34-c884-43e5-9fc2-e569028baf66",
#       "idTo" : "4be9530a-c4d5-47dd-ac60-7d77913331c6"
#     }, {
#       "idFrom" : "62abfdc5-70c1-47b8-9946-b5f3cde1bc9c",
#       "idTo" : "bd824919-f844-40da-8c01-8ca766fde5ac"
#     }, {
#       "idFrom" : "4be9530a-c4d5-47dd-ac60-7d77913331c6",
#       "idTo" : "62abfdc5-70c1-47b8-9946-b5f3cde1bc9c"
#     }, {
#       "idFrom" : "9b6a6735-068a-4c6b-ad80-0d741485e688",
#       "idTo" : "012ae70f-f5f1-4b81-9090-16f02cef75c9"
#     }, {
#       "idFrom" : "9f8165ca-d083-48f2-999f-978d6f5019d5",
#       "idTo" : "6b1d66b3-577e-4667-9c08-4477fd3f321b"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
#  9 cooking+recipe1m+ede56331fbee463f4d4e08dd63d363bd -1.38792 {
#   "id" : "cooking+recipe1m+ede56331fbee463f4d4e08dd63d363bd",
#   "contents" : "Pasta With Ham and Herbed Cheese. 1 lb whole-wheat spiral shaped pasta 2 (5 ounce) packagessoft herbed cheese (such as Alouette or Boursin ) 14 lb boiled ham, cut into cubes salt and pepper 2 tablespoons fresh parsley, chopped Bring a large pot of salted water to a boil and prepare pasta according to package directions. Set aside 1 cup pasta cooking water and drain pasta. Return pasta to pot; crumble pieces of cheese over pasta. Add ham, salt and pepper to taste and parsley to pasta mixture. Pour in 1/2 cup pasta cooking water and toss or stir until cheese is melted and pasta is coated. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+ede56331fbee463f4d4e08dd63d363bd",
#     "title" : "Pasta With Ham and Herbed Cheese",
#     "sourceUrl" : "http://www.food.com/recipe/pasta-with-ham-and-herbed-cheese-491988",
#     "requirementList" : [ {
#       "uniqueId" : "6893b427-69ca-4e85-b85e-468c4dfe215c",
#       "type" : "HARDWARE",
#       "name" : "1 lb whole-wheat spiral shaped pasta"
#     }, {
#       "uniqueId" : "9c9fbf18-ab1d-43cc-bf43-9da16126d022",
#       "type" : "HARDWARE",
#       "name" : "2 (5 ounce) packagessoft herbed cheese (such as Alouette or Boursin )"
#     }, {
#       "uniqueId" : "9372356d-dab7-4eac-a44c-b6db0427374c",
#       "type" : "HARDWARE",
#       "name" : "14 lb boiled ham, cut into cubes"
#     }, {
#       "uniqueId" : "e4ebb1a9-1b3b-4ee6-a05c-747c511f66c3",
#       "type" : "HARDWARE",
#       "name" : "salt and pepper"
#     }, {
#       "uniqueId" : "1e2741b2-4ebb-4eaf-953e-8a76059eb233",
#       "type" : "HARDWARE",
#       "name" : "2 tablespoons fresh parsley, chopped"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "d3319cb8-054b-4af9-b25e-d3fbc457a183",
#       "response" : {
#         "speechText" : "Bring a large pot of salted water to a boil and prepare pasta according to package directions.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Bring a large pot of salted water to a boil and prepare pasta according to package directions." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "2e1632f1-6b43-4b40-a0d5-bba8dab0b20a",
#       "response" : {
#         "speechText" : "Set aside 1 cup pasta cooking water and drain pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Set aside 1 cup pasta cooking water and drain pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "344d6ee9-6116-4306-800a-e881197dd1be",
#       "response" : {
#         "speechText" : "Return pasta to pot; crumble pieces of cheese over pasta.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Return pasta to pot; crumble pieces of cheese over pasta." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "6a52833e-c445-48ae-9d8d-075fb7b54cad",
#       "response" : {
#         "speechText" : "Add ham, salt and pepper to taste and parsley to pasta mixture.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add ham, salt and pepper to taste and parsley to pasta mixture." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "2c24340c-a63e-47db-9adc-eae1b521a586",
#       "response" : {
#         "speechText" : "Pour in 1/2 cup pasta cooking water and toss or stir until cheese is melted and pasta is coated.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Pour in 1/2 cup pasta cooking water and toss or stir until cheese is melted and pasta is coated." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "344d6ee9-6116-4306-800a-e881197dd1be",
#       "idTo" : "6a52833e-c445-48ae-9d8d-075fb7b54cad"
#     }, {
#       "idFrom" : "6a52833e-c445-48ae-9d8d-075fb7b54cad",
#       "idTo" : "2c24340c-a63e-47db-9adc-eae1b521a586"
#     }, {
#       "idFrom" : "d3319cb8-054b-4af9-b25e-d3fbc457a183",
#       "idTo" : "2e1632f1-6b43-4b40-a0d5-bba8dab0b20a"
#     }, {
#       "idFrom" : "2e1632f1-6b43-4b40-a0d5-bba8dab0b20a",
#       "idTo" : "344d6ee9-6116-4306-800a-e881197dd1be"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
# 10 cooking+recipe1m+3ebad90707700cc139a470c1932de761 -3.83782 {
#   "id" : "cooking+recipe1m+3ebad90707700cc139a470c1932de761",
#   "contents" : "Love-Soup Mix in a Jar. 13 cup beef bouillon granules 14 cup dried onion flakes 12 cup split peas 12 cup abc pasta (any small pasta will work) or 12 cup small shell pasta (any small pasta will work) or 12 cup pasta, rings (any small pasta will work) or 12 cup macaroni (any small pasta will work) 14 cup barley 12 cup lentils 13 cup non-instant white rice tri-color spiral pasta Be sure to use a wide-mouth 1qt. canning jars. Layer ingredients in the jar:. Bouillon, Onion Flakes, Split Peas, Small Shape Pasta, Barley, Lentils, Rice and enough tricolored spiral pasta to fill the jar. Attach a tag with cooking instructions: In a large kettle, brown 1 pound ground beef, or stew beef cut into bite-sized pieces, in a little olive oil. Remove tricolored pasta from top of jar and reserve. Add the rest of the jar contents to the kettle with 12 cups water. Let it come to a boil and simmer 45 minutes. ",
#   "recipe_document_json" : {
#     "taskmapId" : "cooking+recipe1m+3ebad90707700cc139a470c1932de761",
#     "title" : "Love-Soup Mix in a Jar",
#     "sourceUrl" : "http://www.food.com/recipe/love-soup-mix-in-a-jar-51972",
#     "requirementList" : [ {
#       "uniqueId" : "2d319bba-82a9-44ff-a99f-0aa63065ad79",
#       "type" : "HARDWARE",
#       "name" : "13 cup beef bouillon granules"
#     }, {
#       "uniqueId" : "257dd664-c80c-487f-a7fd-1f91cac8ff57",
#       "type" : "HARDWARE",
#       "name" : "14 cup dried onion flakes"
#     }, {
#       "uniqueId" : "b02d1a9f-2583-4f6d-99ee-a9cc3cfac64d",
#       "type" : "HARDWARE",
#       "name" : "12 cup split peas"
#     }, {
#       "uniqueId" : "241cd141-1406-4e0d-a48c-3f75ec828ecb",
#       "type" : "HARDWARE",
#       "name" : "12 cup abc pasta (any small pasta will work) or 12 cup small shell pasta (any small pasta will work) or 12 cup pasta, rings (any small pasta will work) or 12 cup macaroni (any small pasta will work)"
#     }, {
#       "uniqueId" : "092902b9-aef3-4eb3-923b-ad1581f0af90",
#       "type" : "HARDWARE",
#       "name" : "14 cup barley"
#     }, {
#       "uniqueId" : "48c69430-2723-4a54-bc05-5d9a13302269",
#       "type" : "HARDWARE",
#       "name" : "12 cup lentils"
#     }, {
#       "uniqueId" : "e4d17231-4b0e-47d4-8020-e2b5bb3ace9e",
#       "type" : "HARDWARE",
#       "name" : "13 cup non-instant white rice"
#     }, {
#       "uniqueId" : "0ac520f9-42c0-4862-aa47-6d317883d275",
#       "type" : "HARDWARE",
#       "name" : "tri-color spiral pasta"
#     } ],
#     "steps" : [ {
#       "uniqueId" : "af3bce30-d364-43a5-980d-6083f94bef98",
#       "response" : {
#         "speechText" : "Be sure to use a wide-mouth 1qt.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Be sure to use a wide-mouth 1qt." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "f3c55ca9-414b-4747-acf3-140e42021321",
#       "response" : {
#         "speechText" : "canning jars.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "canning jars." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "e64f4dc6-7e1d-4993-9ff3-7926d2c5e1bd",
#       "response" : {
#         "speechText" : "Layer ingredients in the jar:.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Layer ingredients in the jar:." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "2e43498d-66b3-4b7c-ba7e-fd3a37558cc4",
#       "response" : {
#         "speechText" : "Bouillon, Onion Flakes, Split Peas, Small Shape Pasta, Barley, Lentils, Rice and enough tricolored spiral pasta to fill the jar.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Bouillon, Onion Flakes, Split Peas, Small Shape Pasta, Barley, Lentils, Rice and enough tricolored spiral pasta to fill the jar." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "2a74134a-e688-4380-bb18-859def5d2ff6",
#       "response" : {
#         "speechText" : "Attach a tag with cooking instructions: In a large kettle, brown 1 pound ground beef, or stew beef cut into bite-sized pieces, in a little olive oil.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Attach a tag with cooking instructions: In a large kettle, brown 1 pound ground beef, or stew beef cut into bite-sized pieces, in a little olive oil." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "f1400c4b-aea6-4ec3-b41d-de9e50a529e4",
#       "response" : {
#         "speechText" : "Remove tricolored pasta from top of jar and reserve.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Remove tricolored pasta from top of jar and reserve." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "73ca199c-6a24-4bf8-82e3-f0a9191bacca",
#       "response" : {
#         "speechText" : "Add the rest of the jar contents to the kettle with 12 cups water.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Add the rest of the jar contents to the kettle with 12 cups water." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     }, {
#       "uniqueId" : "5816843a-ac92-4238-b714-9174d8b6ae50",
#       "response" : {
#         "speechText" : "Let it come to a boil and simmer 45 minutes.",
#         "screen" : {
#           "format" : "TEXT_IMAGE",
#           "headline" : "Step %d out of %d",
#           "paragraphs" : [ "Let it come to a boil and simmer 45 minutes." ]
#         }
#       },
#       "activeDurationMinutes" : 1,
#       "totalDurationMinutes" : 1
#     } ],
#     "connectionList" : [ {
#       "idFrom" : "2a74134a-e688-4380-bb18-859def5d2ff6",
#       "idTo" : "f1400c4b-aea6-4ec3-b41d-de9e50a529e4"
#     }, {
#       "idFrom" : "2e43498d-66b3-4b7c-ba7e-fd3a37558cc4",
#       "idTo" : "2a74134a-e688-4380-bb18-859def5d2ff6"
#     }, {
#       "idFrom" : "73ca199c-6a24-4bf8-82e3-f0a9191bacca",
#       "idTo" : "5816843a-ac92-4238-b714-9174d8b6ae50"
#     }, {
#       "idFrom" : "f3c55ca9-414b-4747-acf3-140e42021321",
#       "idTo" : "e64f4dc6-7e1d-4993-9ff3-7926d2c5e1bd"
#     }, {
#       "idFrom" : "e64f4dc6-7e1d-4993-9ff3-7926d2c5e1bd",
#       "idTo" : "2e43498d-66b3-4b7c-ba7e-fd3a37558cc4"
#     }, {
#       "idFrom" : "af3bce30-d364-43a5-980d-6083f94bef98",
#       "idTo" : "f3c55ca9-414b-4747-acf3-140e42021321"
#     }, {
#       "idFrom" : "f1400c4b-aea6-4ec3-b41d-de9e50a529e4",
#       "idTo" : "73ca199c-6a24-4bf8-82e3-f0a9191bacca"
#     } ],
#     "dataset" : "recipe1m",
#     "domainName" : "food"
#   }
# }
